# %% [markdown]
# ## Model

# %%
"""GCN using DGL nn package

References:
- Semi-Supervised Classification with Graph Convolutional Networks
- Paper: https://arxiv.org/abs/1609.02907
- Code: https://github.com/tkipf/gcn
"""
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import functional as F
from dgl.nn.pytorch import GraphConv


class GCN(nn.Module):
    def __init__(self,
                 g,
                 in_feats,
                 n_hidden,
                 n_classes,
                 activation,
                 dropout=0.5):
        super(GCN, self).__init__()

        self.g = g

        self.gcn_layer1 = GraphConv(in_feats, n_hidden, activation=activation)

        self.gcn_layer2 = GraphConv(n_hidden, n_classes)

        self.dropout = nn.Dropout(p=dropout)

    def forward(self, features):
        h = features

        h = self.gcn_layer1(self.g, h)

        h = self.dropout(h)

        h = self.gcn_layer2(self.g, h)

        return h

    def freeze_features(self, freeze):
        self.emb.weight.requires_grad = not freeze

    def freeze_graph(self, freeze):
        self.gcn_layer1.weight.requires_grad = not freeze
        self.gcn_layer2.weight.requires_grad = not freeze

# %% [markdown]
# ## Functions

# %%
import time

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
def get_masks(n,
              main_ids,
              main_labels,
              test_ratio,
              val_ratio,
              seed=1):
    """
    Randomly splits data into train/val/test using random seed
    returns masks instead of the data itself  
    """
    train_mask = np.zeros(n)
    val_mask = np.zeros(n)
    test_mask = np.zeros(n)

    x_dev, x_test, y_dev, y_test = train_test_split(main_ids,
                                                    main_labels,
                                                    stratify=main_labels,
                                                    test_size=test_ratio,
                                                    random_state=seed)

    x_train, x_val, y_train, y_val = train_test_split(x_dev,
                                                      y_dev,
                                                      stratify=y_dev,
                                                      test_size=val_ratio,
                                                      random_state=seed)

    train_mask[x_train] = 1
    val_mask[x_val] = 1
    test_mask[x_test] = 1

    return train_mask, val_mask, test_mask

# %%
def evaluate(model, features, labels, mask):
    """
    Evaluate model quality (F1-score)
    """
    model.eval()
    with torch.no_grad():
        logits = model(features)
        logits = logits[mask]
        labels = labels[mask].detach().cpu().numpy()
        _, predicted = torch.max(logits, dim=1)
        predicted = predicted.detach().cpu().numpy()
        f1 = f1_score(labels, predicted, average='micro')
        return f1

# %%
### REPLACE HERE WITH YOUR MODEL

MODEL = GCN

# %%
import numpy as np
import dgl
from dgl import DGLGraph

def train_gcn_lp(graph,
              features,
              labels,
              seed=1,
              n_hidden=64,
              n_epochs=200,
              lr=1e-2,
              weight_decay=5e-4,
              dropout=0.5,
              verbose=True,
              cuda=False):

    features = torch.FloatTensor(features)
    labels = torch.LongTensor(labels)
    
    mask = []
    for i in range(len(labels)):
        # nodes with labels
        if graph.nodes[i]['is_main']:
            mask.append(1)
        else:
            mask.append(0)
            
    mask = torch.BoolTensor(mask)
        

    if cuda:
        torch.cuda.set_device("cuda:0")
        features = features.cuda()
        labels = labels.cuda()
        train_mask = train_mask.cuda()
        val_mask = val_mask.cuda()
        test_mask = test_mask.cuda()

    g = DGLGraph(graph)
    g = dgl.transform.add_self_loop(g)
    n_edges = g.number_of_edges()

    degs = g.in_degrees().float()
    norm = torch.pow(degs, -0.5)
    norm[torch.isinf(norm)] = 0

    if cuda:
        norm = norm.cuda()

    g.ndata['norm'] = norm.unsqueeze(1)

    in_feats = features.shape[1]

    # + 1 for unknown class
    n_classes = len(np.unique(labels))
    
    ##########
    ##########  HERE WE USE MODEL
    ##########
    model = MODEL(g,
                in_feats=in_feats,
                n_hidden=n_hidden,
                n_classes=n_classes,
                activation=F.relu,
                dropout=dropout)
    if cuda:
        model.cuda()

    loss_fcn = torch.nn.CrossEntropyLoss()

    # use optimizer
    optimizer = torch.optim.Adam(model.parameters(),
                                 lr=lr,
                                 weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                           mode='min',
                                                           factor=0.9,
                                                           patience=20,
                                                           min_lr=1e-10)

    best_f1 = -100
    # initialize graph
    dur = []
    for epoch in range(n_epochs):
        model.train()
        if epoch >= 3:
            t0 = time.time()
        logits = model(features)
        loss = loss_fcn(logits[mask], labels[mask])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if epoch >= 3:
            dur.append(time.time() - t0)

        f1 = evaluate(model, features, labels, mask)
        scheduler.step(1 - f1)
        if f1 > best_f1:
            best_f1 = f1
            torch.save(model.state_dict(), 'best_model.pt')

        if verbose:
            print("Epoch {:05d} | Time(s) {:.4f} | Loss {:.4f} | F1 {:.4f} | "
                  "ETputs(KTEPS) {:.2f}".format(epoch, np.mean(dur), loss.item(),
                                                f1, n_edges / np.mean(dur) / 1000))

    model.load_state_dict(torch.load('best_model.pt'))
    
    embeddings = model.gcn_layer1(model.g, features).detach().cpu().numpy()

    return embeddings

# %% [markdown]
# ## LP Model

# %%
from models.base_model import BaseModel

class GCN_Model_LP(BaseModel):
    def __init__(self, graph, features, labels=None, dim=80):
        super(GCN_Model_LP, self).__init__(graph, features, dim, labels)

    def learn_embeddings(self):
        embeddings = train_gcn_lp(self.graph, self.features, self.labels)
        self.embeddings = embeddings

# %% [markdown]
# ## Experiments

# %%
from datasets import Cora, CiteseerM10, Dblp

datasets = [
   ('Cora', Cora),
   # ('CiteseerM10', CiteseerM10),
   # ('DBLP', Dblp)
]


from text_transformers import SBert, LDA, W2V, Sent2Vec, Doc2Vec, BOW, TFIDF

tasks = [
    ('GCN (W2V)', lambda ds: LpTask(ds, test_ratios, W2V, GCN_Model_LP, d=100, labels=True))
]

# %%
seeds = [1]
test_ratios = [0.5, 0.7, 0.9, 0.95]

# %%
from tqdm import tqdm
from task import LpTask

res = {}

for ds_name, ds_constr in tqdm(datasets, desc='datasets'):
    ds = ds_constr()
    for task_name, task_constr in tqdm(tasks, desc='Tasks'):
        task = task_constr(ds)
        task_res = task.evaluate()
        for test_ratio in task_res:
            scores = task_res[test_ratio]
            res[f'{1 - test_ratio:.2f} - {ds_name} - {task_name}'] = scores

        print(res)
# Out:
# datasets:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Tasks:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# test_ratios:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# seeds:   0%|          | 0/1 [00:00<?, ?it/s]/Users/mikhail-makarov/opt/anaconda3/envs/graph_text/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/mikhail-makarov/opt/anaconda3/envs/graph_text/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch 00000 | Time(s) nan | Loss 1.9530 | F1 0.3024 | ETputs(KTEPS) nan
# Epoch 00001 | Time(s) nan | Loss 1.8601 | F1 0.3021 | ETputs(KTEPS) nan
# Epoch 00002 | Time(s) nan | Loss 1.8078 | F1 0.3021 | ETputs(KTEPS) nan
# Epoch 00003 | Time(s) 0.0111 | Loss 1.8001 | F1 0.3021 | ETputs(KTEPS) 717.33
# Epoch 00004 | Time(s) 0.0101 | Loss 1.7741 | F1 0.3021 | ETputs(KTEPS) 792.89
# Epoch 00005 | Time(s) 0.0096 | Loss 1.7514 | F1 0.3021 | ETputs(KTEPS) 832.07
# Epoch 00006 | Time(s) 0.0096 | Loss 1.7234 | F1 0.3039 | ETputs(KTEPS) 831.72
# Epoch 00007 | Time(s) 0.0093 | Loss 1.6966 | F1 0.3091 | ETputs(KTEPS) 855.21
# Epoch 00008 | Time(s) 0.0091 | Loss 1.6575 | F1 0.3216 | ETputs(KTEPS) 875.98
# Epoch 00009 | Time(s) 0.0091 | Loss 1.6459 | F1 0.3268 | ETputs(KTEPS) 882.43
# Epoch 00010 | Time(s) 0.0089 | Loss 1.6179 | F1 0.3320 | ETputs(KTEPS) 895.35
# Epoch 00011 | Time(s) 0.0089 | Loss 1.5871 | F1 0.3545 | ETputs(KTEPS) 901.30
# Epoch 00012 | Time(s) 0.0088 | Loss 1.5532 | F1 0.3859 | ETputs(KTEPS) 910.69
# Epoch 00013 | Time(s) 0.0087 | Loss 1.5356 | F1 0.4394 | ETputs(KTEPS) 915.17
# Epoch 00014 | Time(s) 0.0087 | Loss 1.5078 | F1 0.4993 | ETputs(KTEPS) 913.17
# Epoch 00015 | Time(s) 0.0087 | Loss 1.4641 | F1 0.5436 | ETputs(KTEPS) 917.29
# Epoch 00016 | Time(s) 0.0087 | Loss 1.4402 | F1 0.5720 | ETputs(KTEPS) 922.59
# Epoch 00017 | Time(s) 0.0086 | Loss 1.4125 | F1 0.5835 | ETputs(KTEPS) 925.69
# Epoch 00018 | Time(s) 0.0086 | Loss 1.3675 | F1 0.5916 | ETputs(KTEPS) 929.70
# Epoch 00019 | Time(s) 0.0085 | Loss 1.3460 | F1 0.6038 | ETputs(KTEPS) 934.47
# Epoch 00020 | Time(s) 0.0086 | Loss 1.3137 | F1 0.6152 | ETputs(KTEPS) 933.67
# Epoch 00021 | Time(s) 0.0085 | Loss 1.2935 | F1 0.6296 | ETputs(KTEPS) 937.53
# Epoch 00022 | Time(s) 0.0085 | Loss 1.2654 | F1 0.6436 | ETputs(KTEPS) 940.45
# Epoch 00023 | Time(s) 0.0085 | Loss 1.2342 | F1 0.6636 | ETputs(KTEPS) 943.34
# Epoch 00024 | Time(s) 0.0085 | Loss 1.2097 | F1 0.6754 | ETputs(KTEPS) 943.19
# Epoch 00025 | Time(s) 0.0084 | Loss 1.1954 | F1 0.6721 | ETputs(KTEPS) 946.14
# Epoch 00026 | Time(s) 0.0084 | Loss 1.1567 | F1 0.6717 | ETputs(KTEPS) 948.50
# Epoch 00027 | Time(s) 0.0084 | Loss 1.1501 | F1 0.6747 | ETputs(KTEPS) 949.92
# Epoch 00028 | Time(s) 0.0084 | Loss 1.1186 | F1 0.6809 | ETputs(KTEPS) 953.07
# Epoch 00029 | Time(s) 0.0084 | Loss 1.0812 | F1 0.6935 | ETputs(KTEPS) 953.09
# Epoch 00030 | Time(s) 0.0084 | Loss 1.0837 | F1 0.7083 | ETputs(KTEPS) 953.47
# Epoch 00031 | Time(s) 0.0084 | Loss 1.0452 | F1 0.7149 | ETputs(KTEPS) 953.76
# Epoch 00032 | Time(s) 0.0084 | Loss 1.0225 | F1 0.7194 | ETputs(KTEPS) 955.42
# Epoch 00033 | Time(s) 0.0084 | Loss 1.0131 | F1 0.7201 | ETputs(KTEPS) 953.79
# Epoch 00034 | Time(s) 0.0084 | Loss 1.0115 | F1 0.7227 | ETputs(KTEPS) 949.78
# Epoch 00035 | Time(s) 0.0084 | Loss 0.9924 | F1 0.7267 | ETputs(KTEPS) 950.90
# Epoch 00036 | Time(s) 0.0084 | Loss 0.9811 | F1 0.7312 | ETputs(KTEPS) 952.08
# Epoch 00037 | Time(s) 0.0084 | Loss 0.9645 | F1 0.7341 | ETputs(KTEPS) 952.42
# Epoch 00038 | Time(s) 0.0084 | Loss 0.9429 | F1 0.7371 | ETputs(KTEPS) 952.98
# Epoch 00039 | Time(s) 0.0084 | Loss 0.9274 | F1 0.7408 | ETputs(KTEPS) 950.32
# Epoch 00040 | Time(s) 0.0084 | Loss 0.9281 | F1 0.7482 | ETputs(KTEPS) 951.71
# Epoch 00041 | Time(s) 0.0084 | Loss 0.9004 | F1 0.7478 | ETputs(KTEPS) 953.03
# Epoch 00042 | Time(s) 0.0084 | Loss 0.8986 | F1 0.7489 | ETputs(KTEPS) 954.61
# Epoch 00043 | Time(s) 0.0084 | Loss 0.8772 | F1 0.7474 | ETputs(KTEPS) 955.49
# Epoch 00044 | Time(s) 0.0084 | Loss 0.8803 | F1 0.7526 | ETputs(KTEPS) 954.56
# Epoch 00045 | Time(s) 0.0084 | Loss 0.8584 | F1 0.7618 | ETputs(KTEPS) 955.97
# Epoch 00046 | Time(s) 0.0083 | Loss 0.8555 | F1 0.7622 | ETputs(KTEPS) 956.87
# Epoch 00047 | Time(s) 0.0083 | Loss 0.8526 | F1 0.7707 | ETputs(KTEPS) 957.94
# Epoch 00048 | Time(s) 0.0083 | Loss 0.8316 | F1 0.7703 | ETputs(KTEPS) 958.59
# Epoch 00049 | Time(s) 0.0083 | Loss 0.8243 | F1 0.7707 | ETputs(KTEPS) 959.21
# Epoch 00050 | Time(s) 0.0083 | Loss 0.8121 | F1 0.7722 | ETputs(KTEPS) 959.44
# Epoch 00051 | Time(s) 0.0083 | Loss 0.8123 | F1 0.7736 | ETputs(KTEPS) 960.22
# Epoch 00052 | Time(s) 0.0083 | Loss 0.7885 | F1 0.7829 | ETputs(KTEPS) 959.98
# Epoch 00053 | Time(s) 0.0083 | Loss 0.7961 | F1 0.7858 | ETputs(KTEPS) 959.89
# Epoch 00054 | Time(s) 0.0083 | Loss 0.7747 | F1 0.7847 | ETputs(KTEPS) 959.94
# Epoch 00055 | Time(s) 0.0083 | Loss 0.7805 | F1 0.7836 | ETputs(KTEPS) 958.36
# Epoch 00056 | Time(s) 0.0084 | Loss 0.7592 | F1 0.7925 | ETputs(KTEPS) 956.02
# Epoch 00057 | Time(s) 0.0084 | Loss 0.7545 | F1 0.8017 | ETputs(KTEPS) 949.54
# Epoch 00058 | Time(s) 0.0086 | Loss 0.7444 | F1 0.8061 | ETputs(KTEPS) 931.56
# Epoch 00059 | Time(s) 0.0087 | Loss 0.7467 | F1 0.8035 | ETputs(KTEPS) 918.84
# Epoch 00060 | Time(s) 0.0090 | Loss 0.7471 | F1 0.7991 | ETputs(KTEPS) 888.99
# Epoch 00061 | Time(s) 0.0091 | Loss 0.7338 | F1 0.8050 | ETputs(KTEPS) 873.94
# Epoch 00062 | Time(s) 0.0094 | Loss 0.7309 | F1 0.8157 | ETputs(KTEPS) 850.60
# Epoch 00063 | Time(s) 0.0096 | Loss 0.7083 | F1 0.8161 | ETputs(KTEPS) 832.52
# Epoch 00064 | Time(s) 0.0097 | Loss 0.7271 | F1 0.8143 | ETputs(KTEPS) 820.58
# Epoch 00065 | Time(s) 0.0099 | Loss 0.7038 | F1 0.8135 | ETputs(KTEPS) 807.55
# Epoch 00066 | Time(s) 0.0100 | Loss 0.7020 | F1 0.8187 | ETputs(KTEPS) 797.53
# Epoch 00067 | Time(s) 0.0102 | Loss 0.6977 | F1 0.8268 | ETputs(KTEPS) 782.07
# Epoch 00068 | Time(s) 0.0104 | Loss 0.6910 | F1 0.8275 | ETputs(KTEPS) 771.36
# Epoch 00069 | Time(s) 0.0104 | Loss 0.6877 | F1 0.8227 | ETputs(KTEPS) 767.87
# Epoch 00070 | Time(s) 0.0105 | Loss 0.6875 | F1 0.8242 | ETputs(KTEPS) 763.05
# Epoch 00071 | Time(s) 0.0105 | Loss 0.6753 | F1 0.8298 | ETputs(KTEPS) 761.09
# Epoch 00072 | Time(s) 0.0106 | Loss 0.6796 | F1 0.8316 | ETputs(KTEPS) 754.54
# Epoch 00073 | Time(s) 0.0107 | Loss 0.6728 | F1 0.8335 | ETputs(KTEPS) 744.69
# Epoch 00074 | Time(s) 0.0110 | Loss 0.6656 | F1 0.8357 | ETputs(KTEPS) 728.36
# Epoch 00075 | Time(s) 0.0111 | Loss 0.6650 | F1 0.8342 | ETputs(KTEPS) 717.15
# Epoch 00076 | Time(s) 0.0113 | Loss 0.6531 | F1 0.8364 | ETputs(KTEPS) 706.46
# Epoch 00077 | Time(s) 0.0114 | Loss 0.6400 | F1 0.8412 | ETputs(KTEPS) 701.50
# Epoch 00078 | Time(s) 0.0114 | Loss 0.6423 | F1 0.8434 | ETputs(KTEPS) 699.37
# Epoch 00079 | Time(s) 0.0114 | Loss 0.6418 | F1 0.8460 | ETputs(KTEPS) 698.91
# Epoch 00080 | Time(s) 0.0114 | Loss 0.6484 | F1 0.8442 | ETputs(KTEPS) 699.98
# Epoch 00081 | Time(s) 0.0114 | Loss 0.6394 | F1 0.8468 | ETputs(KTEPS) 700.31
# Epoch 00082 | Time(s) 0.0114 | Loss 0.6245 | F1 0.8482 | ETputs(KTEPS) 700.16
# Epoch 00083 | Time(s) 0.0114 | Loss 0.6271 | F1 0.8482 | ETputs(KTEPS) 698.87
# Epoch 00084 | Time(s) 0.0115 | Loss 0.6342 | F1 0.8530 | ETputs(KTEPS) 692.14
# Epoch 00085 | Time(s) 0.0116 | Loss 0.6162 | F1 0.8504 | ETputs(KTEPS) 689.13
# Epoch 00086 | Time(s) 0.0116 | Loss 0.6207 | F1 0.8493 | ETputs(KTEPS) 687.07
# Epoch 00087 | Time(s) 0.0117 | Loss 0.6246 | F1 0.8497 | ETputs(KTEPS) 684.72
# Epoch 00088 | Time(s) 0.0117 | Loss 0.6116 | F1 0.8527 | ETputs(KTEPS) 683.02
# Epoch 00089 | Time(s) 0.0117 | Loss 0.6060 | F1 0.8567 | ETputs(KTEPS) 680.13
# Epoch 00090 | Time(s) 0.0118 | Loss 0.5955 | F1 0.8541 | ETputs(KTEPS) 678.85
# Epoch 00091 | Time(s) 0.0118 | Loss 0.6057 | F1 0.8527 | ETputs(KTEPS) 677.85
# Epoch 00092 | Time(s) 0.0118 | Loss 0.6044 | F1 0.8597 | ETputs(KTEPS) 676.31
# Epoch 00093 | Time(s) 0.0118 | Loss 0.5971 | F1 0.8597 | ETputs(KTEPS) 674.91
# Epoch 00094 | Time(s) 0.0119 | Loss 0.5840 | F1 0.8589 | ETputs(KTEPS) 672.87
# Epoch 00095 | Time(s) 0.0119 | Loss 0.5916 | F1 0.8586 | ETputs(KTEPS) 670.92
# Epoch 00096 | Time(s) 0.0119 | Loss 0.5849 | F1 0.8615 | ETputs(KTEPS) 668.94
# Epoch 00097 | Time(s) 0.0120 | Loss 0.5818 | F1 0.8648 | ETputs(KTEPS) 666.98
# Epoch 00098 | Time(s) 0.0120 | Loss 0.5908 | F1 0.8652 | ETputs(KTEPS) 665.77
# Epoch 00099 | Time(s) 0.0120 | Loss 0.5851 | F1 0.8626 | ETputs(KTEPS) 664.53
# Epoch 00100 | Time(s) 0.0120 | Loss 0.5836 | F1 0.8652 | ETputs(KTEPS) 663.76
# Epoch 00101 | Time(s) 0.0120 | Loss 0.5679 | F1 0.8656 | ETputs(KTEPS) 663.87
# Epoch 00102 | Time(s) 0.0120 | Loss 0.5585 | F1 0.8674 | ETputs(KTEPS) 663.03
# Epoch 00103 | Time(s) 0.0120 | Loss 0.5746 | F1 0.8660 | ETputs(KTEPS) 663.17
# Epoch 00104 | Time(s) 0.0120 | Loss 0.5674 | F1 0.8615 | ETputs(KTEPS) 662.92
# Epoch 00105 | Time(s) 0.0121 | Loss 0.5677 | F1 0.8623 | ETputs(KTEPS) 662.20
# Epoch 00106 | Time(s) 0.0121 | Loss 0.5537 | F1 0.8704 | ETputs(KTEPS) 661.57
# Epoch 00107 | Time(s) 0.0121 | Loss 0.5618 | F1 0.8708 | ETputs(KTEPS) 660.70
# Epoch 00108 | Time(s) 0.0121 | Loss 0.5517 | F1 0.8689 | ETputs(KTEPS) 660.83
# Epoch 00109 | Time(s) 0.0121 | Loss 0.5598 | F1 0.8652 | ETputs(KTEPS) 661.22
# Epoch 00110 | Time(s) 0.0121 | Loss 0.5595 | F1 0.8682 | ETputs(KTEPS) 661.62
# Epoch 00111 | Time(s) 0.0121 | Loss 0.5434 | F1 0.8737 | ETputs(KTEPS) 661.22
# Epoch 00112 | Time(s) 0.0121 | Loss 0.5391 | F1 0.8759 | ETputs(KTEPS) 661.53
# Epoch 00113 | Time(s) 0.0121 | Loss 0.5418 | F1 0.8756 | ETputs(KTEPS) 662.27
# Epoch 00114 | Time(s) 0.0121 | Loss 0.5375 | F1 0.8700 | ETputs(KTEPS) 662.11
# Epoch 00115 | Time(s) 0.0121 | Loss 0.5446 | F1 0.8715 | ETputs(KTEPS) 662.06
# Epoch 00116 | Time(s) 0.0121 | Loss 0.5382 | F1 0.8733 | ETputs(KTEPS) 661.70
# Epoch 00117 | Time(s) 0.0121 | Loss 0.5252 | F1 0.8744 | ETputs(KTEPS) 660.60
# Epoch 00118 | Time(s) 0.0121 | Loss 0.5325 | F1 0.8759 | ETputs(KTEPS) 660.11
# Epoch 00119 | Time(s) 0.0121 | Loss 0.5338 | F1 0.8756 | ETputs(KTEPS) 658.99
# Epoch 00120 | Time(s) 0.0121 | Loss 0.5253 | F1 0.8785 | ETputs(KTEPS) 658.22
# Epoch 00121 | Time(s) 0.0121 | Loss 0.5203 | F1 0.8748 | ETputs(KTEPS) 658.16
# Epoch 00122 | Time(s) 0.0122 | Loss 0.5196 | F1 0.8752 | ETputs(KTEPS) 654.63
# Epoch 00123 | Time(s) 0.0122 | Loss 0.5161 | F1 0.8752 | ETputs(KTEPS) 654.30
# Epoch 00124 | Time(s) 0.0122 | Loss 0.5284 | F1 0.8796 | ETputs(KTEPS) 654.81
# Epoch 00125 | Time(s) 0.0122 | Loss 0.5162 | F1 0.8800 | ETputs(KTEPS) 655.02
# Epoch 00126 | Time(s) 0.0122 | Loss 0.5301 | F1 0.8800 | ETputs(KTEPS) 654.90
# Epoch 00127 | Time(s) 0.0123 | Loss 0.5241 | F1 0.8792 | ETputs(KTEPS) 648.83
# Epoch 00128 | Time(s) 0.0124 | Loss 0.5212 | F1 0.8796 | ETputs(KTEPS) 646.48
# Epoch 00129 | Time(s) 0.0125 | Loss 0.5122 | F1 0.8800 | ETputs(KTEPS) 639.48
# Epoch 00130 | Time(s) 0.0128 | Loss 0.5203 | F1 0.8826 | ETputs(KTEPS) 626.33
# Epoch 00131 | Time(s) 0.0128 | Loss 0.5351 | F1 0.8833 | ETputs(KTEPS) 625.22
# Epoch 00132 | Time(s) 0.0128 | Loss 0.5104 | F1 0.8822 | ETputs(KTEPS) 623.72
# Epoch 00133 | Time(s) 0.0128 | Loss 0.5157 | F1 0.8781 | ETputs(KTEPS) 623.22
# Epoch 00134 | Time(s) 0.0129 | Loss 0.5146 | F1 0.8792 | ETputs(KTEPS) 619.53
# Epoch 00135 | Time(s) 0.0130 | Loss 0.5137 | F1 0.8840 | ETputs(KTEPS) 613.37
# Epoch 00136 | Time(s) 0.0131 | Loss 0.4974 | F1 0.8811 | ETputs(KTEPS) 611.14
# Epoch 00137 | Time(s) 0.0131 | Loss 0.5027 | F1 0.8822 | ETputs(KTEPS) 610.16
# Epoch 00138 | Time(s) 0.0131 | Loss 0.4968 | F1 0.8826 | ETputs(KTEPS) 609.55
# Epoch 00139 | Time(s) 0.0132 | Loss 0.5037 | F1 0.8833 | ETputs(KTEPS) 605.97
# Epoch 00140 | Time(s) 0.0132 | Loss 0.5062 | F1 0.8844 | ETputs(KTEPS) 604.47
# Epoch 00141 | Time(s) 0.0133 | Loss 0.4881 | F1 0.8866 | ETputs(KTEPS) 602.62
# Epoch 00142 | Time(s) 0.0133 | Loss 0.5085 | F1 0.8829 | ETputs(KTEPS) 600.88
# Epoch 00143 | Time(s) 0.0133 | Loss 0.5055 | F1 0.8833 | ETputs(KTEPS) 600.18
# Epoch 00144 | Time(s) 0.0133 | Loss 0.4963 | F1 0.8855 | ETputs(KTEPS) 599.73
# Epoch 00145 | Time(s) 0.0134 | Loss 0.5008 | F1 0.8852 | ETputs(KTEPS) 597.86
# Epoch 00146 | Time(s) 0.0138 | Loss 0.4943 | F1 0.8818 | ETputs(KTEPS) 578.17
# Epoch 00147 | Time(s) 0.0139 | Loss 0.4906 | F1 0.8870 | ETputs(KTEPS) 575.77
# Epoch 00148 | Time(s) 0.0139 | Loss 0.4905 | F1 0.8896 | ETputs(KTEPS) 573.35
# Epoch 00149 | Time(s) 0.0139 | Loss 0.4990 | F1 0.8863 | ETputs(KTEPS) 572.79
# Epoch 00150 | Time(s) 0.0140 | Loss 0.4918 | F1 0.8877 | ETputs(KTEPS) 571.90
# Epoch 00151 | Time(s) 0.0140 | Loss 0.4829 | F1 0.8888 | ETputs(KTEPS) 570.27
# Epoch 00152 | Time(s) 0.0140 | Loss 0.4753 | F1 0.8863 | ETputs(KTEPS) 570.42
# Epoch 00153 | Time(s) 0.0140 | Loss 0.4773 | F1 0.8870 | ETputs(KTEPS) 569.36
# Epoch 00154 | Time(s) 0.0140 | Loss 0.4887 | F1 0.8874 | ETputs(KTEPS) 568.94
# Epoch 00155 | Time(s) 0.0141 | Loss 0.4794 | F1 0.8863 | ETputs(KTEPS) 566.08
# Epoch 00156 | Time(s) 0.0141 | Loss 0.4772 | F1 0.8885 | ETputs(KTEPS) 565.87
# Epoch 00157 | Time(s) 0.0141 | Loss 0.4931 | F1 0.8892 | ETputs(KTEPS) 566.14
# Epoch 00158 | Time(s) 0.0141 | Loss 0.4756 | F1 0.8900 | ETputs(KTEPS) 566.88
# Epoch 00159 | Time(s) 0.0141 | Loss 0.4822 | F1 0.8900 | ETputs(KTEPS) 567.66
# Epoch 00160 | Time(s) 0.0141 | Loss 0.4720 | F1 0.8907 | ETputs(KTEPS) 568.36
# Epoch 00161 | Time(s) 0.0140 | Loss 0.4736 | F1 0.8918 | ETputs(KTEPS) 569.09
# Epoch 00162 | Time(s) 0.0140 | Loss 0.4845 | F1 0.8918 | ETputs(KTEPS) 569.64
# Epoch 00163 | Time(s) 0.0140 | Loss 0.4666 | F1 0.8896 | ETputs(KTEPS) 570.24
# Epoch 00164 | Time(s) 0.0140 | Loss 0.4819 | F1 0.8900 | ETputs(KTEPS) 570.84
# Epoch 00165 | Time(s) 0.0140 | Loss 0.4613 | F1 0.8925 | ETputs(KTEPS) 571.00
# Epoch 00166 | Time(s) 0.0140 | Loss 0.4532 | F1 0.8933 | ETputs(KTEPS) 570.97
# Epoch 00167 | Time(s) 0.0140 | Loss 0.4646 | F1 0.8936 | ETputs(KTEPS) 570.23
# Epoch 00168 | Time(s) 0.0140 | Loss 0.4713 | F1 0.8936 | ETputs(KTEPS) 568.54
# Epoch 00169 | Time(s) 0.0141 | Loss 0.4731 | F1 0.8907 | ETputs(KTEPS) 566.56
# Epoch 00170 | Time(s) 0.0143 | Loss 0.4525 | F1 0.8925 | ETputs(KTEPS) 557.87
# Epoch 00171 | Time(s) 0.0143 | Loss 0.4665 | F1 0.8881 | ETputs(KTEPS) 558.21
# Epoch 00172 | Time(s) 0.0143 | Loss 0.4698 | F1 0.8933 | ETputs(KTEPS) 558.46
# Epoch 00173 | Time(s) 0.0143 | Loss 0.4561 | F1 0.8903 | ETputs(KTEPS) 558.31
# Epoch 00174 | Time(s) 0.0143 | Loss 0.4718 | F1 0.8918 | ETputs(KTEPS) 558.17
# Epoch 00175 | Time(s) 0.0143 | Loss 0.4579 | F1 0.8914 | ETputs(KTEPS) 558.94
# Epoch 00176 | Time(s) 0.0143 | Loss 0.4632 | F1 0.8925 | ETputs(KTEPS) 559.41
# Epoch 00177 | Time(s) 0.0143 | Loss 0.4526 | F1 0.8933 | ETputs(KTEPS) 559.66
# Epoch 00178 | Time(s) 0.0143 | Loss 0.4710 | F1 0.8925 | ETputs(KTEPS) 559.91
# Epoch 00179 | Time(s) 0.0143 | Loss 0.4681 | F1 0.8940 | ETputs(KTEPS) 560.23
# Epoch 00180 | Time(s) 0.0142 | Loss 0.4558 | F1 0.8925 | ETputs(KTEPS) 560.87
# Epoch 00181 | Time(s) 0.0143 | Loss 0.4651 | F1 0.8922 | ETputs(KTEPS) 558.20
# Epoch 00182 | Time(s) 0.0143 | Loss 0.4606 | F1 0.8922 | ETputs(KTEPS) 557.09
# Epoch 00183 | Time(s) 0.0144 | Loss 0.4665 | F1 0.8948 | ETputs(KTEPS) 556.08
# Epoch 00184 | Time(s) 0.0144 | Loss 0.4617 | F1 0.8914 | ETputs(KTEPS) 555.59
# Epoch 00185 | Time(s) 0.0144 | Loss 0.4485 | F1 0.8944 | ETputs(KTEPS) 554.30
# Epoch 00186 | Time(s) 0.0144 | Loss 0.4427 | F1 0.8933 | ETputs(KTEPS) 554.24
# Epoch 00187 | Time(s) 0.0144 | Loss 0.4597 | F1 0.8936 | ETputs(KTEPS) 553.98
# Epoch 00188 | Time(s) 0.0144 | Loss 0.4560 | F1 0.8903 | ETputs(KTEPS) 554.21
# Epoch 00189 | Time(s) 0.0144 | Loss 0.4479 | F1 0.8940 | ETputs(KTEPS) 554.02
# Epoch 00190 | Time(s) 0.0144 | Loss 0.4579 | F1 0.8944 | ETputs(KTEPS) 554.18
# Epoch 00191 | Time(s) 0.0144 | Loss 0.4422 | F1 0.8944 | ETputs(KTEPS) 552.87
# Epoch 00192 | Time(s) 0.0146 | Loss 0.4480 | F1 0.8925 | ETputs(KTEPS) 546.43
# Epoch 00193 | Time(s) 0.0147 | Loss 0.4493 | F1 0.8922 | ETputs(KTEPS) 543.35
# Epoch 00194 | Time(s) 0.0148 | Loss 0.4440 | F1 0.8955 | ETputs(KTEPS) 540.12
# Epoch 00195 | Time(s) 0.0148 | Loss 0.4488 | F1 0.8936 | ETputs(KTEPS) 538.78
# Epoch 00196 | Time(s) 0.0150 | Loss 0.4474 | F1 0.8936 | ETputs(KTEPS) 532.62
# Epoch 00197 | Time(s) 0.0150 | Loss 0.4478 | F1 0.8959 | ETputs(KTEPS) 532.19
# Epoch 00198 | Time(s) 0.0150 | Loss 0.4434 | F1 0.8970 | ETputs(KTEPS) 531.53
# Epoch 00199 | Time(s) 0.0151 | Loss 0.4559 | F1 0.8966 | ETputs(KTEPS) 529.62
# /Users/mikhail-makarov/opt/anaconda3/envs/graph_text/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#
#
#
#
#
#
#
#
#
#
#
#
#
# seeds: 100%|██████████| 1/1 [00:06<00:00,  6.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# test_ratios:  25%|██▌       | 1/4 [00:06<00:19,  6.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# seeds:   0%|          | 0/1 [00:00<?, ?it/s]/Users/mikhail-makarov/opt/anaconda3/envs/graph_text/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/mikhail-makarov/opt/anaconda3/envs/graph_text/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch 00000 | Time(s) nan | Loss 1.9418 | F1 0.3021 | ETputs(KTEPS) nan
# Epoch 00001 | Time(s) nan | Loss 1.8377 | F1 0.3021 | ETputs(KTEPS) nan
# Epoch 00002 | Time(s) nan | Loss 1.8096 | F1 0.3021 | ETputs(KTEPS) nan
# Epoch 00003 | Time(s) 0.0176 | Loss 1.7858 | F1 0.3021 | ETputs(KTEPS) 334.72
# Epoch 00004 | Time(s) 0.0163 | Loss 1.7617 | F1 0.3131 | ETputs(KTEPS) 360.51
# Epoch 00005 | Time(s) 0.0179 | Loss 1.7391 | F1 0.3383 | ETputs(KTEPS) 328.66
# Epoch 00006 | Time(s) 0.0182 | Loss 1.7193 | F1 0.3261 | ETputs(KTEPS) 323.68
# Epoch 00007 | Time(s) 0.0187 | Loss 1.6774 | F1 0.3146 | ETputs(KTEPS) 314.21
# Epoch 00008 | Time(s) 0.0203 | Loss 1.6483 | F1 0.3176 | ETputs(KTEPS) 288.94
# Epoch 00009 | Time(s) 0.0209 | Loss 1.6226 | F1 0.3301 | ETputs(KTEPS) 280.91
# Epoch 00010 | Time(s) 0.0212 | Loss 1.5883 | F1 0.3578 | ETputs(KTEPS) 276.86
# Epoch 00011 | Time(s) 0.0213 | Loss 1.5694 | F1 0.4184 | ETputs(KTEPS) 275.98
# Epoch 00012 | Time(s) 0.0216 | Loss 1.5252 | F1 0.4985 | ETputs(KTEPS) 272.40
# Epoch 00013 | Time(s) 0.0220 | Loss 1.5000 | F1 0.5547 | ETputs(KTEPS) 267.57
# Epoch 00014 | Time(s) 0.0222 | Loss 1.4673 | F1 0.5790 | ETputs(KTEPS) 264.15
# Epoch 00015 | Time(s) 0.0223 | Loss 1.4463 | F1 0.5835 | ETputs(KTEPS) 263.29
# Epoch 00016 | Time(s) 0.0223 | Loss 1.4156 | F1 0.5905 | ETputs(KTEPS) 263.83
# Epoch 00017 | Time(s) 0.0224 | Loss 1.3825 | F1 0.6008 | ETputs(KTEPS) 261.88
# Epoch 00018 | Time(s) 0.0231 | Loss 1.3466 | F1 0.6160 | ETputs(KTEPS) 254.04
# Epoch 00019 | Time(s) 0.0231 | Loss 1.3282 | F1 0.6304 | ETputs(KTEPS) 253.97
# Epoch 00020 | Time(s) 0.0228 | Loss 1.2971 | F1 0.6403 | ETputs(KTEPS) 257.34
# Epoch 00021 | Time(s) 0.0226 | Loss 1.2625 | F1 0.6481 | ETputs(KTEPS) 260.50
# Epoch 00022 | Time(s) 0.0226 | Loss 1.2357 | F1 0.6510 | ETputs(KTEPS) 260.47
# Epoch 00023 | Time(s) 0.0226 | Loss 1.2173 | F1 0.6507 | ETputs(KTEPS) 260.44
# Epoch 00024 | Time(s) 0.0222 | Loss 1.1882 | F1 0.6629 | ETputs(KTEPS) 264.79
# Epoch 00025 | Time(s) 0.0220 | Loss 1.1699 | F1 0.6706 | ETputs(KTEPS) 267.28
# Epoch 00026 | Time(s) 0.0217 | Loss 1.1390 | F1 0.6809 | ETputs(KTEPS) 270.54
# Epoch 00027 | Time(s) 0.0218 | Loss 1.1178 | F1 0.6891 | ETputs(KTEPS) 269.84
# Epoch 00028 | Time(s) 0.0219 | Loss 1.0969 | F1 0.6924 | ETputs(KTEPS) 268.52
# Epoch 00029 | Time(s) 0.0220 | Loss 1.0860 | F1 0.6942 | ETputs(KTEPS) 267.42
# Epoch 00030 | Time(s) 0.0217 | Loss 1.0686 | F1 0.7027 | ETputs(KTEPS) 270.74
# Epoch 00031 | Time(s) 0.0216 | Loss 1.0416 | F1 0.7079 | ETputs(KTEPS) 272.18
# Epoch 00032 | Time(s) 0.0214 | Loss 1.0240 | F1 0.7142 | ETputs(KTEPS) 274.20
# Epoch 00033 | Time(s) 0.0213 | Loss 1.0276 | F1 0.7160 | ETputs(KTEPS) 276.11
# Epoch 00034 | Time(s) 0.0214 | Loss 1.0174 | F1 0.7160 | ETputs(KTEPS) 274.94
# Epoch 00035 | Time(s) 0.0214 | Loss 0.9949 | F1 0.7120 | ETputs(KTEPS) 274.47
# Epoch 00036 | Time(s) 0.0217 | Loss 0.9605 | F1 0.7197 | ETputs(KTEPS) 271.32
# Epoch 00037 | Time(s) 0.0216 | Loss 0.9512 | F1 0.7275 | ETputs(KTEPS) 271.79
# Epoch 00038 | Time(s) 0.0215 | Loss 0.9436 | F1 0.7315 | ETputs(KTEPS) 272.90
# Epoch 00039 | Time(s) 0.0214 | Loss 0.9379 | F1 0.7367 | ETputs(KTEPS) 274.32
# Epoch 00040 | Time(s) 0.0213 | Loss 0.9149 | F1 0.7422 | ETputs(KTEPS) 275.83
# Epoch 00041 | Time(s) 0.0212 | Loss 0.9092 | F1 0.7426 | ETputs(KTEPS) 276.60
# Epoch 00042 | Time(s) 0.0212 | Loss 0.8809 | F1 0.7474 | ETputs(KTEPS) 276.75
# Epoch 00043 | Time(s) 0.0211 | Loss 0.8899 | F1 0.7544 | ETputs(KTEPS) 278.26
# Epoch 00044 | Time(s) 0.0210 | Loss 0.8803 | F1 0.7574 | ETputs(KTEPS) 279.60
# Epoch 00045 | Time(s) 0.0209 | Loss 0.8706 | F1 0.7570 | ETputs(KTEPS) 280.78
# Epoch 00046 | Time(s) 0.0208 | Loss 0.8684 | F1 0.7570 | ETputs(KTEPS) 282.40
# Epoch 00047 | Time(s) 0.0209 | Loss 0.8506 | F1 0.7592 | ETputs(KTEPS) 281.80
# Epoch 00048 | Time(s) 0.0208 | Loss 0.8392 | F1 0.7622 | ETputs(KTEPS) 282.54
# Epoch 00049 | Time(s) 0.0207 | Loss 0.8235 | F1 0.7692 | ETputs(KTEPS) 283.41
# Epoch 00050 | Time(s) 0.0206 | Loss 0.8277 | F1 0.7755 | ETputs(KTEPS) 285.35
# Epoch 00051 | Time(s) 0.0204 | Loss 0.8200 | F1 0.7806 | ETputs(KTEPS) 287.82
# Epoch 00052 | Time(s) 0.0203 | Loss 0.8136 | F1 0.7847 | ETputs(KTEPS) 289.69
# Epoch 00053 | Time(s) 0.0202 | Loss 0.8153 | F1 0.7843 | ETputs(KTEPS) 291.53
# Epoch 00054 | Time(s) 0.0202 | Loss 0.7995 | F1 0.7869 | ETputs(KTEPS) 291.59
# Epoch 00055 | Time(s) 0.0202 | Loss 0.7887 | F1 0.7921 | ETputs(KTEPS) 290.88
# Epoch 00056 | Time(s) 0.0203 | Loss 0.7850 | F1 0.7954 | ETputs(KTEPS) 289.26
# Epoch 00057 | Time(s) 0.0203 | Loss 0.7880 | F1 0.7943 | ETputs(KTEPS) 290.14
# Epoch 00058 | Time(s) 0.0202 | Loss 0.7697 | F1 0.7954 | ETputs(KTEPS) 290.98
# Epoch 00059 | Time(s) 0.0200 | Loss 0.7623 | F1 0.7987 | ETputs(KTEPS) 293.12
# Epoch 00060 | Time(s) 0.0199 | Loss 0.7591 | F1 0.8035 | ETputs(KTEPS) 294.80
# Epoch 00061 | Time(s) 0.0198 | Loss 0.7659 | F1 0.8080 | ETputs(KTEPS) 296.03
# Epoch 00062 | Time(s) 0.0198 | Loss 0.7573 | F1 0.8080 | ETputs(KTEPS) 296.50
# Epoch 00063 | Time(s) 0.0198 | Loss 0.7195 | F1 0.8065 | ETputs(KTEPS) 296.12
# Epoch 00064 | Time(s) 0.0199 | Loss 0.7409 | F1 0.8072 | ETputs(KTEPS) 295.17
# Epoch 00065 | Time(s) 0.0199 | Loss 0.7196 | F1 0.8124 | ETputs(KTEPS) 294.85
# Epoch 00066 | Time(s) 0.0198 | Loss 0.7307 | F1 0.8172 | ETputs(KTEPS) 296.09
# Epoch 00067 | Time(s) 0.0198 | Loss 0.7203 | F1 0.8183 | ETputs(KTEPS) 297.16
# Epoch 00068 | Time(s) 0.0197 | Loss 0.7209 | F1 0.8143 | ETputs(KTEPS) 298.41
# Epoch 00069 | Time(s) 0.0196 | Loss 0.7128 | F1 0.8154 | ETputs(KTEPS) 299.37
# Epoch 00070 | Time(s) 0.0197 | Loss 0.7209 | F1 0.8183 | ETputs(KTEPS) 298.50
# Epoch 00071 | Time(s) 0.0198 | Loss 0.6924 | F1 0.8231 | ETputs(KTEPS) 297.47
# Epoch 00072 | Time(s) 0.0199 | Loss 0.6969 | F1 0.8261 | ETputs(KTEPS) 295.75
# Epoch 00073 | Time(s) 0.0198 | Loss 0.7020 | F1 0.8220 | ETputs(KTEPS) 297.15
# Epoch 00074 | Time(s) 0.0197 | Loss 0.6881 | F1 0.8253 | ETputs(KTEPS) 298.82
# Epoch 00075 | Time(s) 0.0196 | Loss 0.6941 | F1 0.8275 | ETputs(KTEPS) 300.20
# Epoch 00076 | Time(s) 0.0195 | Loss 0.6703 | F1 0.8298 | ETputs(KTEPS) 301.56
# Epoch 00077 | Time(s) 0.0194 | Loss 0.6820 | F1 0.8279 | ETputs(KTEPS) 303.45
# Epoch 00078 | Time(s) 0.0193 | Loss 0.6724 | F1 0.8290 | ETputs(KTEPS) 304.27
# Epoch 00079 | Time(s) 0.0192 | Loss 0.6642 | F1 0.8320 | ETputs(KTEPS) 305.67
# Epoch 00080 | Time(s) 0.0191 | Loss 0.6667 | F1 0.8379 | ETputs(KTEPS) 307.15
# Epoch 00081 | Time(s) 0.0190 | Loss 0.6648 | F1 0.8338 | ETputs(KTEPS) 308.67
# Epoch 00082 | Time(s) 0.0190 | Loss 0.6650 | F1 0.8368 | ETputs(KTEPS) 309.91
# Epoch 00083 | Time(s) 0.0189 | Loss 0.6591 | F1 0.8383 | ETputs(KTEPS) 311.30
# Epoch 00084 | Time(s) 0.0189 | Loss 0.6444 | F1 0.8394 | ETputs(KTEPS) 311.41
# Epoch 00085 | Time(s) 0.0189 | Loss 0.6419 | F1 0.8401 | ETputs(KTEPS) 311.32
# Epoch 00086 | Time(s) 0.0189 | Loss 0.6311 | F1 0.8419 | ETputs(KTEPS) 311.15
# Epoch 00087 | Time(s) 0.0189 | Loss 0.6378 | F1 0.8427 | ETputs(KTEPS) 311.05
# Epoch 00088 | Time(s) 0.0188 | Loss 0.6381 | F1 0.8471 | ETputs(KTEPS) 312.09
# Epoch 00089 | Time(s) 0.0188 | Loss 0.6322 | F1 0.8456 | ETputs(KTEPS) 313.35
# Epoch 00090 | Time(s) 0.0187 | Loss 0.6243 | F1 0.8427 | ETputs(KTEPS) 314.18
# Epoch 00091 | Time(s) 0.0186 | Loss 0.6321 | F1 0.8445 | ETputs(KTEPS) 315.16
# Epoch 00092 | Time(s) 0.0186 | Loss 0.6303 | F1 0.8501 | ETputs(KTEPS) 316.30
# Epoch 00093 | Time(s) 0.0185 | Loss 0.6264 | F1 0.8534 | ETputs(KTEPS) 317.31
# Epoch 00094 | Time(s) 0.0185 | Loss 0.6142 | F1 0.8490 | ETputs(KTEPS) 318.18
# Epoch 00095 | Time(s) 0.0184 | Loss 0.6155 | F1 0.8471 | ETputs(KTEPS) 318.72
# Epoch 00096 | Time(s) 0.0184 | Loss 0.6291 | F1 0.8541 | ETputs(KTEPS) 319.84
# Epoch 00097 | Time(s) 0.0183 | Loss 0.6063 | F1 0.8527 | ETputs(KTEPS) 320.47
# Epoch 00098 | Time(s) 0.0183 | Loss 0.6072 | F1 0.8519 | ETputs(KTEPS) 320.40
# Epoch 00099 | Time(s) 0.0183 | Loss 0.6160 | F1 0.8508 | ETputs(KTEPS) 320.99
# Epoch 00100 | Time(s) 0.0183 | Loss 0.6084 | F1 0.8604 | ETputs(KTEPS) 321.77
# Epoch 00101 | Time(s) 0.0182 | Loss 0.6033 | F1 0.8567 | ETputs(KTEPS) 322.22
# Epoch 00102 | Time(s) 0.0182 | Loss 0.6129 | F1 0.8512 | ETputs(KTEPS) 323.16
# Epoch 00103 | Time(s) 0.0181 | Loss 0.6063 | F1 0.8538 | ETputs(KTEPS) 323.89
# Epoch 00104 | Time(s) 0.0181 | Loss 0.5950 | F1 0.8593 | ETputs(KTEPS) 325.05
# Epoch 00105 | Time(s) 0.0180 | Loss 0.5908 | F1 0.8619 | ETputs(KTEPS) 326.06
# Epoch 00106 | Time(s) 0.0180 | Loss 0.5792 | F1 0.8623 | ETputs(KTEPS) 326.68
# Epoch 00107 | Time(s) 0.0179 | Loss 0.5894 | F1 0.8597 | ETputs(KTEPS) 327.44
# Epoch 00108 | Time(s) 0.0179 | Loss 0.5886 | F1 0.8589 | ETputs(KTEPS) 328.17
# Epoch 00109 | Time(s) 0.0178 | Loss 0.5839 | F1 0.8593 | ETputs(KTEPS) 329.38
# Epoch 00110 | Time(s) 0.0178 | Loss 0.5737 | F1 0.8634 | ETputs(KTEPS) 330.39
# Epoch 00111 | Time(s) 0.0177 | Loss 0.6008 | F1 0.8608 | ETputs(KTEPS) 331.34
# Epoch 00112 | Time(s) 0.0177 | Loss 0.5862 | F1 0.8674 | ETputs(KTEPS) 332.37
# Epoch 00113 | Time(s) 0.0176 | Loss 0.5878 | F1 0.8674 | ETputs(KTEPS) 333.15
# Epoch 00114 | Time(s) 0.0177 | Loss 0.5855 | F1 0.8674 | ETputs(KTEPS) 332.86
# Epoch 00115 | Time(s) 0.0177 | Loss 0.5832 | F1 0.8634 | ETputs(KTEPS) 332.36
# Epoch 00116 | Time(s) 0.0177 | Loss 0.5678 | F1 0.8689 | ETputs(KTEPS) 331.72
# Epoch 00117 | Time(s) 0.0177 | Loss 0.5729 | F1 0.8730 | ETputs(KTEPS) 331.44
# Epoch 00118 | Time(s) 0.0177 | Loss 0.5632 | F1 0.8682 | ETputs(KTEPS) 331.14
# Epoch 00119 | Time(s) 0.0178 | Loss 0.5729 | F1 0.8685 | ETputs(KTEPS) 330.83
# Epoch 00120 | Time(s) 0.0178 | Loss 0.5616 | F1 0.8645 | ETputs(KTEPS) 330.55
# Epoch 00121 | Time(s) 0.0178 | Loss 0.5721 | F1 0.8733 | ETputs(KTEPS) 330.91
# Epoch 00122 | Time(s) 0.0177 | Loss 0.5547 | F1 0.8715 | ETputs(KTEPS) 331.76
# Epoch 00123 | Time(s) 0.0177 | Loss 0.5697 | F1 0.8708 | ETputs(KTEPS) 332.33
# Epoch 00124 | Time(s) 0.0176 | Loss 0.5673 | F1 0.8678 | ETputs(KTEPS) 333.26
# Epoch 00125 | Time(s) 0.0176 | Loss 0.5551 | F1 0.8730 | ETputs(KTEPS) 334.15
# Epoch 00126 | Time(s) 0.0175 | Loss 0.5601 | F1 0.8733 | ETputs(KTEPS) 335.06
# Epoch 00127 | Time(s) 0.0175 | Loss 0.5580 | F1 0.8722 | ETputs(KTEPS) 336.03
# Epoch 00128 | Time(s) 0.0174 | Loss 0.5501 | F1 0.8700 | ETputs(KTEPS) 336.75
# Epoch 00129 | Time(s) 0.0174 | Loss 0.5557 | F1 0.8748 | ETputs(KTEPS) 337.78
# Epoch 00130 | Time(s) 0.0174 | Loss 0.5468 | F1 0.8744 | ETputs(KTEPS) 338.59
# Epoch 00131 | Time(s) 0.0173 | Loss 0.5562 | F1 0.8748 | ETputs(KTEPS) 339.48
# Epoch 00132 | Time(s) 0.0173 | Loss 0.5463 | F1 0.8711 | ETputs(KTEPS) 340.37
# Epoch 00133 | Time(s) 0.0173 | Loss 0.5365 | F1 0.8744 | ETputs(KTEPS) 340.39
# Epoch 00134 | Time(s) 0.0173 | Loss 0.5528 | F1 0.8785 | ETputs(KTEPS) 339.63
# Epoch 00135 | Time(s) 0.0173 | Loss 0.5337 | F1 0.8774 | ETputs(KTEPS) 339.33
# Epoch 00136 | Time(s) 0.0173 | Loss 0.5453 | F1 0.8737 | ETputs(KTEPS) 338.99
# Epoch 00137 | Time(s) 0.0173 | Loss 0.5385 | F1 0.8781 | ETputs(KTEPS) 339.45
# Epoch 00138 | Time(s) 0.0173 | Loss 0.5297 | F1 0.8792 | ETputs(KTEPS) 340.10
# Epoch 00139 | Time(s) 0.0172 | Loss 0.5384 | F1 0.8811 | ETputs(KTEPS) 340.76
# Epoch 00140 | Time(s) 0.0172 | Loss 0.5286 | F1 0.8804 | ETputs(KTEPS) 341.56
# Epoch 00141 | Time(s) 0.0172 | Loss 0.5324 | F1 0.8822 | ETputs(KTEPS) 341.99
# Epoch 00142 | Time(s) 0.0172 | Loss 0.5227 | F1 0.8785 | ETputs(KTEPS) 342.58
# Epoch 00143 | Time(s) 0.0172 | Loss 0.5362 | F1 0.8800 | ETputs(KTEPS) 342.07
# Epoch 00144 | Time(s) 0.0172 | Loss 0.5348 | F1 0.8811 | ETputs(KTEPS) 341.79
# Epoch 00145 | Time(s) 0.0172 | Loss 0.5354 | F1 0.8804 | ETputs(KTEPS) 341.35
# Epoch 00146 | Time(s) 0.0172 | Loss 0.5187 | F1 0.8822 | ETputs(KTEPS) 341.59
# Epoch 00147 | Time(s) 0.0172 | Loss 0.5230 | F1 0.8785 | ETputs(KTEPS) 342.22
# Epoch 00148 | Time(s) 0.0171 | Loss 0.5334 | F1 0.8800 | ETputs(KTEPS) 343.11
# Epoch 00149 | Time(s) 0.0171 | Loss 0.5348 | F1 0.8796 | ETputs(KTEPS) 343.35
# Epoch 00150 | Time(s) 0.0171 | Loss 0.5163 | F1 0.8837 | ETputs(KTEPS) 343.80
# Epoch 00151 | Time(s) 0.0171 | Loss 0.5148 | F1 0.8840 | ETputs(KTEPS) 344.43
# Epoch 00152 | Time(s) 0.0170 | Loss 0.5295 | F1 0.8818 | ETputs(KTEPS) 345.01
# Epoch 00153 | Time(s) 0.0170 | Loss 0.5160 | F1 0.8840 | ETputs(KTEPS) 345.83
# Epoch 00154 | Time(s) 0.0170 | Loss 0.5145 | F1 0.8848 | ETputs(KTEPS) 346.53
# Epoch 00155 | Time(s) 0.0169 | Loss 0.5205 | F1 0.8855 | ETputs(KTEPS) 347.40
# Epoch 00156 | Time(s) 0.0169 | Loss 0.5185 | F1 0.8881 | ETputs(KTEPS) 348.34
# Epoch 00157 | Time(s) 0.0168 | Loss 0.5130 | F1 0.8863 | ETputs(KTEPS) 349.15
# Epoch 00158 | Time(s) 0.0168 | Loss 0.5042 | F1 0.8870 | ETputs(KTEPS) 349.90
# Epoch 00159 | Time(s) 0.0168 | Loss 0.4979 | F1 0.8863 | ETputs(KTEPS) 350.37
# Epoch 00160 | Time(s) 0.0168 | Loss 0.5138 | F1 0.8863 | ETputs(KTEPS) 350.57
# Epoch 00161 | Time(s) 0.0168 | Loss 0.5245 | F1 0.8874 | ETputs(KTEPS) 350.56
# Epoch 00162 | Time(s) 0.0168 | Loss 0.5131 | F1 0.8848 | ETputs(KTEPS) 350.72
# Epoch 00163 | Time(s) 0.0168 | Loss 0.5036 | F1 0.8852 | ETputs(KTEPS) 350.41
# Epoch 00164 | Time(s) 0.0168 | Loss 0.5158 | F1 0.8881 | ETputs(KTEPS) 350.39
# Epoch 00165 | Time(s) 0.0168 | Loss 0.5134 | F1 0.8885 | ETputs(KTEPS) 349.88
# Epoch 00166 | Time(s) 0.0168 | Loss 0.5045 | F1 0.8840 | ETputs(KTEPS) 349.70
# Epoch 00167 | Time(s) 0.0168 | Loss 0.5204 | F1 0.8852 | ETputs(KTEPS) 349.58
# Epoch 00168 | Time(s) 0.0168 | Loss 0.4988 | F1 0.8870 | ETputs(KTEPS) 349.17
# Epoch 00169 | Time(s) 0.0168 | Loss 0.5099 | F1 0.8874 | ETputs(KTEPS) 349.16
# Epoch 00170 | Time(s) 0.0168 | Loss 0.5048 | F1 0.8870 | ETputs(KTEPS) 349.06
# Epoch 00171 | Time(s) 0.0168 | Loss 0.4996 | F1 0.8881 | ETputs(KTEPS) 349.16
# Epoch 00172 | Time(s) 0.0168 | Loss 0.5028 | F1 0.8881 | ETputs(KTEPS) 348.92
# Epoch 00173 | Time(s) 0.0168 | Loss 0.5227 | F1 0.8896 | ETputs(KTEPS) 348.77
# Epoch 00174 | Time(s) 0.0169 | Loss 0.5002 | F1 0.8888 | ETputs(KTEPS) 348.50
# Epoch 00175 | Time(s) 0.0168 | Loss 0.4874 | F1 0.8907 | ETputs(KTEPS) 349.14
# Epoch 00176 | Time(s) 0.0168 | Loss 0.4885 | F1 0.8903 | ETputs(KTEPS) 349.93
# Epoch 00177 | Time(s) 0.0168 | Loss 0.4988 | F1 0.8877 | ETputs(KTEPS) 350.76
# Epoch 00178 | Time(s) 0.0167 | Loss 0.4853 | F1 0.8911 | ETputs(KTEPS) 351.43
# Epoch 00179 | Time(s) 0.0167 | Loss 0.4928 | F1 0.8885 | ETputs(KTEPS) 352.09
# Epoch 00180 | Time(s) 0.0167 | Loss 0.4968 | F1 0.8903 | ETputs(KTEPS) 352.61
# Epoch 00181 | Time(s) 0.0166 | Loss 0.4978 | F1 0.8896 | ETputs(KTEPS) 353.29
# Epoch 00182 | Time(s) 0.0166 | Loss 0.4913 | F1 0.8907 | ETputs(KTEPS) 353.99
# Epoch 00183 | Time(s) 0.0166 | Loss 0.4820 | F1 0.8903 | ETputs(KTEPS) 354.71
# Epoch 00184 | Time(s) 0.0165 | Loss 0.4898 | F1 0.8911 | ETputs(KTEPS) 355.31
# Epoch 00185 | Time(s) 0.0165 | Loss 0.4835 | F1 0.8914 | ETputs(KTEPS) 355.49
# Epoch 00186 | Time(s) 0.0165 | Loss 0.4968 | F1 0.8888 | ETputs(KTEPS) 355.76
# Epoch 00187 | Time(s) 0.0165 | Loss 0.4951 | F1 0.8914 | ETputs(KTEPS) 356.21
# Epoch 00188 | Time(s) 0.0165 | Loss 0.4995 | F1 0.8929 | ETputs(KTEPS) 356.65
# Epoch 00189 | Time(s) 0.0164 | Loss 0.4898 | F1 0.8944 | ETputs(KTEPS) 357.32
# Epoch 00190 | Time(s) 0.0164 | Loss 0.4897 | F1 0.8922 | ETputs(KTEPS) 358.16
# Epoch 00191 | Time(s) 0.0164 | Loss 0.4860 | F1 0.8929 | ETputs(KTEPS) 358.99
# Epoch 00192 | Time(s) 0.0163 | Loss 0.4808 | F1 0.8918 | ETputs(KTEPS) 359.90
# Epoch 00193 | Time(s) 0.0163 | Loss 0.4796 | F1 0.8944 | ETputs(KTEPS) 360.77
# Epoch 00194 | Time(s) 0.0162 | Loss 0.4871 | F1 0.8940 | ETputs(KTEPS) 361.70
# Epoch 00195 | Time(s) 0.0162 | Loss 0.4791 | F1 0.8929 | ETputs(KTEPS) 362.53
# Epoch 00196 | Time(s) 0.0162 | Loss 0.4833 | F1 0.8936 | ETputs(KTEPS) 363.49
# Epoch 00197 | Time(s) 0.0161 | Loss 0.4854 | F1 0.8936 | ETputs(KTEPS) 364.43
# /Users/mikhail-makarov/opt/anaconda3/envs/graph_text/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#
#
#
#
#
#
#
#
#
#
#
#
#
# seeds: 100%|██████████| 1/1 [00:08<00:00,  8.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# test_ratios:  50%|█████     | 2/4 [00:14<00:14,  7.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# seeds:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 00198 | Time(s) 0.0161 | Loss 0.4857 | F1 0.8940 | ETputs(KTEPS) 365.08
# Epoch 00199 | Time(s) 0.0161 | Loss 0.4735 | F1 0.8955 | ETputs(KTEPS) 365.78
# /Users/mikhail-makarov/opt/anaconda3/envs/graph_text/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/mikhail-makarov/opt/anaconda3/envs/graph_text/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch 00000 | Time(s) nan | Loss 1.9571 | F1 0.3017 | ETputs(KTEPS) nan
# Epoch 00001 | Time(s) nan | Loss 1.8530 | F1 0.3021 | ETputs(KTEPS) nan
# Epoch 00002 | Time(s) nan | Loss 1.8081 | F1 0.3021 | ETputs(KTEPS) nan
# Epoch 00003 | Time(s) 0.0084 | Loss 1.7842 | F1 0.3028 | ETputs(KTEPS) 447.89
# Epoch 00004 | Time(s) 0.0083 | Loss 1.7651 | F1 0.3150 | ETputs(KTEPS) 452.93
# Epoch 00005 | Time(s) 0.0082 | Loss 1.7243 | F1 0.3279 | ETputs(KTEPS) 460.60
# Epoch 00006 | Time(s) 0.0081 | Loss 1.6979 | F1 0.3323 | ETputs(KTEPS) 463.73
# Epoch 00007 | Time(s) 0.0081 | Loss 1.6543 | F1 0.3394 | ETputs(KTEPS) 463.92
# Epoch 00008 | Time(s) 0.0083 | Loss 1.6291 | F1 0.3615 | ETputs(KTEPS) 455.69
# Epoch 00009 | Time(s) 0.0089 | Loss 1.6003 | F1 0.4018 | ETputs(KTEPS) 423.56
# Epoch 00010 | Time(s) 0.0091 | Loss 1.5631 | F1 0.4402 | ETputs(KTEPS) 414.64
# Epoch 00011 | Time(s) 0.0092 | Loss 1.5326 | F1 0.4838 | ETputs(KTEPS) 407.16
# Epoch 00012 | Time(s) 0.0092 | Loss 1.4928 | F1 0.5066 | ETputs(KTEPS) 409.70
# Epoch 00013 | Time(s) 0.0092 | Loss 1.4588 | F1 0.5236 | ETputs(KTEPS) 410.99
# Epoch 00014 | Time(s) 0.0091 | Loss 1.4351 | F1 0.5439 | ETputs(KTEPS) 415.04
# Epoch 00015 | Time(s) 0.0090 | Loss 1.4046 | F1 0.5801 | ETputs(KTEPS) 419.05
# Epoch 00016 | Time(s) 0.0089 | Loss 1.3725 | F1 0.6001 | ETputs(KTEPS) 422.81
# Epoch 00017 | Time(s) 0.0088 | Loss 1.3562 | F1 0.6134 | ETputs(KTEPS) 425.95
# Epoch 00018 | Time(s) 0.0088 | Loss 1.3133 | F1 0.6171 | ETputs(KTEPS) 428.68
# Epoch 00019 | Time(s) 0.0088 | Loss 1.3034 | F1 0.6174 | ETputs(KTEPS) 429.86
# Epoch 00020 | Time(s) 0.0087 | Loss 1.2683 | F1 0.6274 | ETputs(KTEPS) 430.99
# Epoch 00021 | Time(s) 0.0087 | Loss 1.2530 | F1 0.6400 | ETputs(KTEPS) 432.80
# Epoch 00022 | Time(s) 0.0087 | Loss 1.2308 | F1 0.6477 | ETputs(KTEPS) 430.80
# Epoch 00023 | Time(s) 0.0089 | Loss 1.2131 | F1 0.6544 | ETputs(KTEPS) 423.79
# Epoch 00024 | Time(s) 0.0092 | Loss 1.1866 | F1 0.6562 | ETputs(KTEPS) 410.29
# Epoch 00025 | Time(s) 0.0093 | Loss 1.1793 | F1 0.6632 | ETputs(KTEPS) 404.49
# Epoch 00026 | Time(s) 0.0092 | Loss 1.1561 | F1 0.6695 | ETputs(KTEPS) 407.11
# Epoch 00027 | Time(s) 0.0092 | Loss 1.1454 | F1 0.6750 | ETputs(KTEPS) 409.69
# Epoch 00028 | Time(s) 0.0091 | Loss 1.1274 | F1 0.6802 | ETputs(KTEPS) 412.15
# Epoch 00029 | Time(s) 0.0091 | Loss 1.1018 | F1 0.6821 | ETputs(KTEPS) 413.42
# Epoch 00030 | Time(s) 0.0091 | Loss 1.0857 | F1 0.6861 | ETputs(KTEPS) 415.29
# Epoch 00031 | Time(s) 0.0090 | Loss 1.0626 | F1 0.6917 | ETputs(KTEPS) 417.09
# Epoch 00032 | Time(s) 0.0090 | Loss 1.0530 | F1 0.6953 | ETputs(KTEPS) 418.48
# Epoch 00033 | Time(s) 0.0090 | Loss 1.0343 | F1 0.6968 | ETputs(KTEPS) 419.72
# Epoch 00034 | Time(s) 0.0089 | Loss 1.0211 | F1 0.7016 | ETputs(KTEPS) 421.13
# Epoch 00035 | Time(s) 0.0089 | Loss 1.0142 | F1 0.7053 | ETputs(KTEPS) 422.41
# Epoch 00036 | Time(s) 0.0089 | Loss 1.0025 | F1 0.7097 | ETputs(KTEPS) 423.86
# Epoch 00037 | Time(s) 0.0089 | Loss 0.9969 | F1 0.7120 | ETputs(KTEPS) 424.54
# Epoch 00038 | Time(s) 0.0088 | Loss 0.9833 | F1 0.7168 | ETputs(KTEPS) 426.09
# Epoch 00039 | Time(s) 0.0089 | Loss 0.9747 | F1 0.7230 | ETputs(KTEPS) 424.38
# Epoch 00040 | Time(s) 0.0090 | Loss 0.9561 | F1 0.7227 | ETputs(KTEPS) 416.41
# Epoch 00041 | Time(s) 0.0091 | Loss 0.9496 | F1 0.7264 | ETputs(KTEPS) 412.64
# Epoch 00042 | Time(s) 0.0092 | Loss 0.9310 | F1 0.7297 | ETputs(KTEPS) 409.17
# Epoch 00043 | Time(s) 0.0092 | Loss 0.9360 | F1 0.7304 | ETputs(KTEPS) 410.13
# Epoch 00044 | Time(s) 0.0092 | Loss 0.9201 | F1 0.7386 | ETputs(KTEPS) 410.16
# Epoch 00045 | Time(s) 0.0091 | Loss 0.9130 | F1 0.7411 | ETputs(KTEPS) 411.56
# Epoch 00046 | Time(s) 0.0091 | Loss 0.9150 | F1 0.7448 | ETputs(KTEPS) 412.98
# Epoch 00047 | Time(s) 0.0091 | Loss 0.9025 | F1 0.7500 | ETputs(KTEPS) 414.13
# Epoch 00048 | Time(s) 0.0091 | Loss 0.8730 | F1 0.7581 | ETputs(KTEPS) 415.55
# Epoch 00049 | Time(s) 0.0090 | Loss 0.8947 | F1 0.7585 | ETputs(KTEPS) 416.81
# Epoch 00050 | Time(s) 0.0090 | Loss 0.8678 | F1 0.7603 | ETputs(KTEPS) 417.77
# Epoch 00051 | Time(s) 0.0090 | Loss 0.8730 | F1 0.7629 | ETputs(KTEPS) 418.81
# Epoch 00052 | Time(s) 0.0090 | Loss 0.8586 | F1 0.7674 | ETputs(KTEPS) 417.38
# Epoch 00053 | Time(s) 0.0096 | Loss 0.8354 | F1 0.7718 | ETputs(KTEPS) 392.22
# Epoch 00054 | Time(s) 0.0100 | Loss 0.8362 | F1 0.7755 | ETputs(KTEPS) 375.12
# Epoch 00055 | Time(s) 0.0106 | Loss 0.8312 | F1 0.7803 | ETputs(KTEPS) 354.07
# Epoch 00056 | Time(s) 0.0108 | Loss 0.8428 | F1 0.7799 | ETputs(KTEPS) 348.80
# Epoch 00057 | Time(s) 0.0109 | Loss 0.8258 | F1 0.7810 | ETputs(KTEPS) 344.53
# Epoch 00058 | Time(s) 0.0117 | Loss 0.8186 | F1 0.7814 | ETputs(KTEPS) 322.74
# Epoch 00059 | Time(s) 0.0122 | Loss 0.8131 | F1 0.7829 | ETputs(KTEPS) 309.50
# Epoch 00060 | Time(s) 0.0122 | Loss 0.7994 | F1 0.7851 | ETputs(KTEPS) 309.74
# Epoch 00061 | Time(s) 0.0122 | Loss 0.8104 | F1 0.7895 | ETputs(KTEPS) 307.96
# Epoch 00062 | Time(s) 0.0124 | Loss 0.7937 | F1 0.7925 | ETputs(KTEPS) 302.39
# Epoch 00063 | Time(s) 0.0126 | Loss 0.7843 | F1 0.7939 | ETputs(KTEPS) 299.39
# Epoch 00064 | Time(s) 0.0127 | Loss 0.7737 | F1 0.7954 | ETputs(KTEPS) 297.36
# Epoch 00065 | Time(s) 0.0127 | Loss 0.7811 | F1 0.7965 | ETputs(KTEPS) 295.43
# Epoch 00066 | Time(s) 0.0128 | Loss 0.7551 | F1 0.7984 | ETputs(KTEPS) 294.54
# Epoch 00067 | Time(s) 0.0128 | Loss 0.7683 | F1 0.8039 | ETputs(KTEPS) 294.67
# Epoch 00068 | Time(s) 0.0129 | Loss 0.7642 | F1 0.8047 | ETputs(KTEPS) 292.85
# Epoch 00069 | Time(s) 0.0129 | Loss 0.7588 | F1 0.8054 | ETputs(KTEPS) 291.85
# Epoch 00070 | Time(s) 0.0129 | Loss 0.7439 | F1 0.8072 | ETputs(KTEPS) 290.74
# Epoch 00071 | Time(s) 0.0130 | Loss 0.7486 | F1 0.8076 | ETputs(KTEPS) 289.27
# Epoch 00072 | Time(s) 0.0131 | Loss 0.7447 | F1 0.8076 | ETputs(KTEPS) 286.30
# Epoch 00073 | Time(s) 0.0132 | Loss 0.7492 | F1 0.8083 | ETputs(KTEPS) 284.35
# Epoch 00074 | Time(s) 0.0134 | Loss 0.7421 | F1 0.8080 | ETputs(KTEPS) 281.62
# Epoch 00075 | Time(s) 0.0134 | Loss 0.7429 | F1 0.8143 | ETputs(KTEPS) 281.16
# Epoch 00076 | Time(s) 0.0134 | Loss 0.7380 | F1 0.8120 | ETputs(KTEPS) 280.04
# Epoch 00077 | Time(s) 0.0134 | Loss 0.7297 | F1 0.8124 | ETputs(KTEPS) 280.54
# Epoch 00078 | Time(s) 0.0136 | Loss 0.7204 | F1 0.8150 | ETputs(KTEPS) 276.25
# Epoch 00079 | Time(s) 0.0139 | Loss 0.7113 | F1 0.8220 | ETputs(KTEPS) 270.48
# Epoch 00080 | Time(s) 0.0140 | Loss 0.7186 | F1 0.8202 | ETputs(KTEPS) 268.37
# Epoch 00081 | Time(s) 0.0142 | Loss 0.7187 | F1 0.8187 | ETputs(KTEPS) 265.61
# Epoch 00082 | Time(s) 0.0143 | Loss 0.7159 | F1 0.8216 | ETputs(KTEPS) 263.96
# Epoch 00083 | Time(s) 0.0146 | Loss 0.6972 | F1 0.8231 | ETputs(KTEPS) 257.68
# Epoch 00084 | Time(s) 0.0148 | Loss 0.7065 | F1 0.8239 | ETputs(KTEPS) 254.05
# Epoch 00085 | Time(s) 0.0149 | Loss 0.6896 | F1 0.8257 | ETputs(KTEPS) 252.73
# Epoch 00086 | Time(s) 0.0150 | Loss 0.6974 | F1 0.8294 | ETputs(KTEPS) 251.74
# Epoch 00087 | Time(s) 0.0149 | Loss 0.6957 | F1 0.8327 | ETputs(KTEPS) 252.46
# Epoch 00088 | Time(s) 0.0149 | Loss 0.6970 | F1 0.8290 | ETputs(KTEPS) 252.71
# Epoch 00089 | Time(s) 0.0149 | Loss 0.6832 | F1 0.8290 | ETputs(KTEPS) 253.36
# Epoch 00090 | Time(s) 0.0149 | Loss 0.6913 | F1 0.8305 | ETputs(KTEPS) 253.26
# Epoch 00091 | Time(s) 0.0148 | Loss 0.6844 | F1 0.8368 | ETputs(KTEPS) 253.79
# Epoch 00092 | Time(s) 0.0148 | Loss 0.6815 | F1 0.8375 | ETputs(KTEPS) 254.53
# Epoch 00093 | Time(s) 0.0148 | Loss 0.6808 | F1 0.8346 | ETputs(KTEPS) 254.97
# Epoch 00094 | Time(s) 0.0147 | Loss 0.6784 | F1 0.8346 | ETputs(KTEPS) 255.75
# Epoch 00095 | Time(s) 0.0147 | Loss 0.6736 | F1 0.8383 | ETputs(KTEPS) 255.99
# Epoch 00096 | Time(s) 0.0147 | Loss 0.6629 | F1 0.8401 | ETputs(KTEPS) 256.48
# Epoch 00097 | Time(s) 0.0146 | Loss 0.6625 | F1 0.8383 | ETputs(KTEPS) 257.04
# Epoch 00098 | Time(s) 0.0146 | Loss 0.6668 | F1 0.8368 | ETputs(KTEPS) 257.75
# Epoch 00099 | Time(s) 0.0146 | Loss 0.6704 | F1 0.8434 | ETputs(KTEPS) 258.00
# Epoch 00100 | Time(s) 0.0145 | Loss 0.6572 | F1 0.8401 | ETputs(KTEPS) 258.71
# Epoch 00101 | Time(s) 0.0146 | Loss 0.6540 | F1 0.8412 | ETputs(KTEPS) 257.13
# Epoch 00102 | Time(s) 0.0147 | Loss 0.6697 | F1 0.8419 | ETputs(KTEPS) 256.62
# Epoch 00103 | Time(s) 0.0146 | Loss 0.6589 | F1 0.8456 | ETputs(KTEPS) 257.11
# Epoch 00104 | Time(s) 0.0146 | Loss 0.6632 | F1 0.8427 | ETputs(KTEPS) 257.69
# Epoch 00105 | Time(s) 0.0146 | Loss 0.6522 | F1 0.8419 | ETputs(KTEPS) 258.05
# Epoch 00106 | Time(s) 0.0146 | Loss 0.6566 | F1 0.8453 | ETputs(KTEPS) 258.65
# Epoch 00107 | Time(s) 0.0145 | Loss 0.6428 | F1 0.8449 | ETputs(KTEPS) 259.48
# Epoch 00108 | Time(s) 0.0145 | Loss 0.6373 | F1 0.8434 | ETputs(KTEPS) 260.26
# Epoch 00109 | Time(s) 0.0144 | Loss 0.6513 | F1 0.8482 | ETputs(KTEPS) 261.00
# Epoch 00110 | Time(s) 0.0144 | Loss 0.6397 | F1 0.8504 | ETputs(KTEPS) 261.65
# Epoch 00111 | Time(s) 0.0143 | Loss 0.6358 | F1 0.8504 | ETputs(KTEPS) 262.42
# Epoch 00112 | Time(s) 0.0143 | Loss 0.6176 | F1 0.8442 | ETputs(KTEPS) 263.23
# Epoch 00113 | Time(s) 0.0143 | Loss 0.6150 | F1 0.8497 | ETputs(KTEPS) 263.84
# Epoch 00114 | Time(s) 0.0143 | Loss 0.6334 | F1 0.8519 | ETputs(KTEPS) 264.12
# Epoch 00115 | Time(s) 0.0142 | Loss 0.6319 | F1 0.8530 | ETputs(KTEPS) 264.89
# Epoch 00116 | Time(s) 0.0142 | Loss 0.6359 | F1 0.8468 | ETputs(KTEPS) 265.38
# Epoch 00117 | Time(s) 0.0142 | Loss 0.6278 | F1 0.8519 | ETputs(KTEPS) 265.67
# Epoch 00118 | Time(s) 0.0141 | Loss 0.6211 | F1 0.8560 | ETputs(KTEPS) 266.15
# Epoch 00119 | Time(s) 0.0141 | Loss 0.6213 | F1 0.8534 | ETputs(KTEPS) 266.59
# Epoch 00120 | Time(s) 0.0141 | Loss 0.6251 | F1 0.8497 | ETputs(KTEPS) 266.97
# Epoch 00121 | Time(s) 0.0141 | Loss 0.6226 | F1 0.8538 | ETputs(KTEPS) 267.34
# Epoch 00122 | Time(s) 0.0141 | Loss 0.6123 | F1 0.8545 | ETputs(KTEPS) 267.81
# Epoch 00123 | Time(s) 0.0140 | Loss 0.6171 | F1 0.8575 | ETputs(KTEPS) 268.29
# Epoch 00124 | Time(s) 0.0140 | Loss 0.6156 | F1 0.8497 | ETputs(KTEPS) 268.60
# Epoch 00125 | Time(s) 0.0140 | Loss 0.6152 | F1 0.8582 | ETputs(KTEPS) 269.22
# Epoch 00126 | Time(s) 0.0139 | Loss 0.6046 | F1 0.8589 | ETputs(KTEPS) 269.82
# Epoch 00127 | Time(s) 0.0139 | Loss 0.6128 | F1 0.8575 | ETputs(KTEPS) 270.49
# Epoch 00128 | Time(s) 0.0139 | Loss 0.6057 | F1 0.8545 | ETputs(KTEPS) 271.29
# Epoch 00129 | Time(s) 0.0138 | Loss 0.6063 | F1 0.8619 | ETputs(KTEPS) 272.03
# Epoch 00130 | Time(s) 0.0138 | Loss 0.6116 | F1 0.8612 | ETputs(KTEPS) 272.84
# Epoch 00131 | Time(s) 0.0138 | Loss 0.5968 | F1 0.8597 | ETputs(KTEPS) 273.40
# Epoch 00132 | Time(s) 0.0137 | Loss 0.6019 | F1 0.8600 | ETputs(KTEPS) 273.85
# Epoch 00133 | Time(s) 0.0137 | Loss 0.6105 | F1 0.8623 | ETputs(KTEPS) 274.25
# Epoch 00134 | Time(s) 0.0137 | Loss 0.6046 | F1 0.8656 | ETputs(KTEPS) 274.73
# Epoch 00135 | Time(s) 0.0137 | Loss 0.6003 | F1 0.8630 | ETputs(KTEPS) 275.35
# Epoch 00136 | Time(s) 0.0136 | Loss 0.6006 | F1 0.8630 | ETputs(KTEPS) 276.02
# Epoch 00137 | Time(s) 0.0136 | Loss 0.6004 | F1 0.8641 | ETputs(KTEPS) 276.90
# Epoch 00138 | Time(s) 0.0136 | Loss 0.6093 | F1 0.8626 | ETputs(KTEPS) 277.76
# Epoch 00139 | Time(s) 0.0135 | Loss 0.6033 | F1 0.8641 | ETputs(KTEPS) 278.35
# Epoch 00140 | Time(s) 0.0135 | Loss 0.6007 | F1 0.8648 | ETputs(KTEPS) 278.84
# Epoch 00141 | Time(s) 0.0135 | Loss 0.5824 | F1 0.8671 | ETputs(KTEPS) 279.39
# Epoch 00142 | Time(s) 0.0135 | Loss 0.5866 | F1 0.8652 | ETputs(KTEPS) 279.81
# Epoch 00143 | Time(s) 0.0134 | Loss 0.5878 | F1 0.8648 | ETputs(KTEPS) 280.17
# Epoch 00144 | Time(s) 0.0134 | Loss 0.5843 | F1 0.8674 | ETputs(KTEPS) 280.56
# Epoch 00145 | Time(s) 0.0134 | Loss 0.5864 | F1 0.8660 | ETputs(KTEPS) 280.19
# Epoch 00146 | Time(s) 0.0135 | Loss 0.5742 | F1 0.8663 | ETputs(KTEPS) 279.73
# Epoch 00147 | Time(s) 0.0135 | Loss 0.5917 | F1 0.8667 | ETputs(KTEPS) 279.64
# Epoch 00148 | Time(s) 0.0134 | Loss 0.5801 | F1 0.8689 | ETputs(KTEPS) 279.97
# Epoch 00149 | Time(s) 0.0134 | Loss 0.5640 | F1 0.8693 | ETputs(KTEPS) 280.74
# Epoch 00150 | Time(s) 0.0134 | Loss 0.5865 | F1 0.8704 | ETputs(KTEPS) 281.01
# Epoch 00151 | Time(s) 0.0134 | Loss 0.5870 | F1 0.8711 | ETputs(KTEPS) 281.32
# Epoch 00152 | Time(s) 0.0134 | Loss 0.5779 | F1 0.8696 | ETputs(KTEPS) 281.51
# Epoch 00153 | Time(s) 0.0133 | Loss 0.5783 | F1 0.8696 | ETputs(KTEPS) 281.98
# Epoch 00154 | Time(s) 0.0134 | Loss 0.5814 | F1 0.8682 | ETputs(KTEPS) 281.83
# Epoch 00155 | Time(s) 0.0133 | Loss 0.5798 | F1 0.8715 | ETputs(KTEPS) 282.14
# Epoch 00156 | Time(s) 0.0133 | Loss 0.5724 | F1 0.8685 | ETputs(KTEPS) 282.46
# Epoch 00157 | Time(s) 0.0133 | Loss 0.5755 | F1 0.8700 | ETputs(KTEPS) 282.40
# Epoch 00158 | Time(s) 0.0133 | Loss 0.5741 | F1 0.8741 | ETputs(KTEPS) 282.34
# Epoch 00159 | Time(s) 0.0133 | Loss 0.5741 | F1 0.8733 | ETputs(KTEPS) 282.57
# Epoch 00160 | Time(s) 0.0133 | Loss 0.5773 | F1 0.8696 | ETputs(KTEPS) 282.59
# Epoch 00161 | Time(s) 0.0133 | Loss 0.5694 | F1 0.8685 | ETputs(KTEPS) 282.72
# Epoch 00162 | Time(s) 0.0133 | Loss 0.5727 | F1 0.8741 | ETputs(KTEPS) 282.79
# Epoch 00163 | Time(s) 0.0133 | Loss 0.5691 | F1 0.8730 | ETputs(KTEPS) 282.86
# Epoch 00164 | Time(s) 0.0133 | Loss 0.5627 | F1 0.8726 | ETputs(KTEPS) 282.26
# Epoch 00165 | Time(s) 0.0133 | Loss 0.5565 | F1 0.8756 | ETputs(KTEPS) 282.31
# Epoch 00166 | Time(s) 0.0133 | Loss 0.5681 | F1 0.8759 | ETputs(KTEPS) 282.36
# Epoch 00167 | Time(s) 0.0133 | Loss 0.5686 | F1 0.8708 | ETputs(KTEPS) 282.55
# Epoch 00168 | Time(s) 0.0133 | Loss 0.5709 | F1 0.8711 | ETputs(KTEPS) 282.34
# Epoch 00169 | Time(s) 0.0133 | Loss 0.5708 | F1 0.8741 | ETputs(KTEPS) 282.61
# Epoch 00170 | Time(s) 0.0133 | Loss 0.5621 | F1 0.8752 | ETputs(KTEPS) 282.89
# Epoch 00171 | Time(s) 0.0133 | Loss 0.5664 | F1 0.8756 | ETputs(KTEPS) 283.21
# Epoch 00172 | Time(s) 0.0133 | Loss 0.5642 | F1 0.8767 | ETputs(KTEPS) 283.42
# Epoch 00173 | Time(s) 0.0133 | Loss 0.5611 | F1 0.8752 | ETputs(KTEPS) 283.61
# Epoch 00174 | Time(s) 0.0133 | Loss 0.5571 | F1 0.8781 | ETputs(KTEPS) 283.68
# Epoch 00175 | Time(s) 0.0134 | Loss 0.5495 | F1 0.8767 | ETputs(KTEPS) 280.94
# Epoch 00176 | Time(s) 0.0134 | Loss 0.5540 | F1 0.8733 | ETputs(KTEPS) 280.34
# Epoch 00177 | Time(s) 0.0134 | Loss 0.5457 | F1 0.8741 | ETputs(KTEPS) 280.12
# Epoch 00178 | Time(s) 0.0134 | Loss 0.5424 | F1 0.8778 | ETputs(KTEPS) 279.92
# Epoch 00179 | Time(s) 0.0134 | Loss 0.5646 | F1 0.8807 | ETputs(KTEPS) 280.02
# Epoch 00180 | Time(s) 0.0134 | Loss 0.5554 | F1 0.8792 | ETputs(KTEPS) 280.20
# Epoch 00181 | Time(s) 0.0134 | Loss 0.5460 | F1 0.8789 | ETputs(KTEPS) 280.46
# Epoch 00182 | Time(s) 0.0134 | Loss 0.5508 | F1 0.8744 | ETputs(KTEPS) 280.72
# Epoch 00183 | Time(s) 0.0134 | Loss 0.5409 | F1 0.8796 | ETputs(KTEPS) 280.66
# Epoch 00184 | Time(s) 0.0134 | Loss 0.5455 | F1 0.8804 | ETputs(KTEPS) 280.60
# Epoch 00185 | Time(s) 0.0134 | Loss 0.5654 | F1 0.8800 | ETputs(KTEPS) 280.61
# Epoch 00186 | Time(s) 0.0134 | Loss 0.5459 | F1 0.8852 | ETputs(KTEPS) 280.44
# ...
# Epoch 00005 | Time(s) 0.0080 | Loss 1.7264 | F1 0.3375 | ETputs(KTEPS) 405.60
# Epoch 00006 | Time(s) 0.0081 | Loss 1.7013 | F1 0.3434 | ETputs(KTEPS) 401.69
# Epoch 00007 | Time(s) 0.0080 | Loss 1.6790 | F1 0.3490 | ETputs(KTEPS) 403.73
# Epoch 00008 | Time(s) 0.0080 | Loss 1.6428 | F1 0.3549 | ETputs(KTEPS) 405.16
# Epoch 00009 | Time(s) 0.0080 | Loss 1.6017 | F1 0.3719 | ETputs(KTEPS) 405.38
# Epoch 00010 | Time(s) 0.0080 | Loss 1.5757 | F1 0.3981 | ETputs(KTEPS) 406.12
# Epoch 00011 | Time(s) 0.0080 | Loss 1.5513 | F1 0.4324 | ETputs(KTEPS) 405.89
# Epoch 00012 | Time(s) 0.0080 | Loss 1.5248 | F1 0.4645 | ETputs(KTEPS) 403.47
# Epoch 00013 | Time(s) 0.0081 | Loss 1.5017 | F1 0.4956 | ETputs(KTEPS) 400.66
# Epoch 00014 | Time(s) 0.0082 | Loss 1.4722 | F1 0.5266 | ETputs(KTEPS) 393.82
# Epoch 00015 | Time(s) 0.0083 | Loss 1.4477 | F1 0.5391 | ETputs(KTEPS) 391.22
# Epoch 00016 | Time(s) 0.0083 | Loss 1.4206 | F1 0.5532 | ETputs(KTEPS) 388.63
# Epoch 00017 | Time(s) 0.0084 | Loss 1.3969 | F1 0.5687 | ETputs(KTEPS) 385.08
# Epoch 00018 | Time(s) 0.0084 | Loss 1.3734 | F1 0.5879 | ETputs(KTEPS) 387.31
# Epoch 00019 | Time(s) 0.0083 | Loss 1.3511 | F1 0.6027 | ETputs(KTEPS) 388.96
# Epoch 00020 | Time(s) 0.0083 | Loss 1.3246 | F1 0.6145 | ETputs(KTEPS) 390.15
# Epoch 00021 | Time(s) 0.0083 | Loss 1.3116 | F1 0.6204 | ETputs(KTEPS) 391.20
# Epoch 00022 | Time(s) 0.0082 | Loss 1.2900 | F1 0.6226 | ETputs(KTEPS) 392.33
# Epoch 00023 | Time(s) 0.0082 | Loss 1.2613 | F1 0.6315 | ETputs(KTEPS) 392.61
# Epoch 00024 | Time(s) 0.0082 | Loss 1.2505 | F1 0.6411 | ETputs(KTEPS) 393.14
# Epoch 00025 | Time(s) 0.0082 | Loss 1.2182 | F1 0.6481 | ETputs(KTEPS) 393.69
# Epoch 00026 | Time(s) 0.0082 | Loss 1.2105 | F1 0.6610 | ETputs(KTEPS) 393.98
# Epoch 00027 | Time(s) 0.0082 | Loss 1.1974 | F1 0.6621 | ETputs(KTEPS) 393.76
# Epoch 00028 | Time(s) 0.0082 | Loss 1.1981 | F1 0.6669 | ETputs(KTEPS) 393.12
# Epoch 00029 | Time(s) 0.0082 | Loss 1.1603 | F1 0.6702 | ETputs(KTEPS) 392.65
# Epoch 00030 | Time(s) 0.0083 | Loss 1.1541 | F1 0.6750 | ETputs(KTEPS) 391.81
# Epoch 00031 | Time(s) 0.0083 | Loss 1.1362 | F1 0.6795 | ETputs(KTEPS) 390.41
# Epoch 00032 | Time(s) 0.0083 | Loss 1.1205 | F1 0.6817 | ETputs(KTEPS) 389.17
# Epoch 00033 | Time(s) 0.0083 | Loss 1.1148 | F1 0.6846 | ETputs(KTEPS) 388.34
# Epoch 00034 | Time(s) 0.0083 | Loss 1.0821 | F1 0.6880 | ETputs(KTEPS) 387.58
# Epoch 00035 | Time(s) 0.0083 | Loss 1.0863 | F1 0.6865 | ETputs(KTEPS) 388.60
# Epoch 00036 | Time(s) 0.0083 | Loss 1.0678 | F1 0.6905 | ETputs(KTEPS) 388.67
# Epoch 00037 | Time(s) 0.0083 | Loss 1.0701 | F1 0.6953 | ETputs(KTEPS) 388.66
# Epoch 00038 | Time(s) 0.0083 | Loss 1.0551 | F1 0.6987 | ETputs(KTEPS) 389.00
# Epoch 00039 | Time(s) 0.0083 | Loss 1.0410 | F1 0.7031 | ETputs(KTEPS) 388.46
# Epoch 00040 | Time(s) 0.0083 | Loss 1.0402 | F1 0.7038 | ETputs(KTEPS) 387.79
# Epoch 00041 | Time(s) 0.0083 | Loss 1.0109 | F1 0.7049 | ETputs(KTEPS) 387.69
# Epoch 00042 | Time(s) 0.0084 | Loss 1.0138 | F1 0.7105 | ETputs(KTEPS) 386.67
# Epoch 00043 | Time(s) 0.0084 | Loss 0.9879 | F1 0.7123 | ETputs(KTEPS) 386.17
# Epoch 00044 | Time(s) 0.0084 | Loss 0.9834 | F1 0.7145 | ETputs(KTEPS) 386.38
# Epoch 00045 | Time(s) 0.0084 | Loss 0.9746 | F1 0.7197 | ETputs(KTEPS) 386.55
# Epoch 00046 | Time(s) 0.0083 | Loss 0.9790 | F1 0.7253 | ETputs(KTEPS) 387.62
# Epoch 00047 | Time(s) 0.0083 | Loss 0.9570 | F1 0.7290 | ETputs(KTEPS) 388.46
# Epoch 00048 | Time(s) 0.0083 | Loss 0.9589 | F1 0.7323 | ETputs(KTEPS) 389.44
# Epoch 00049 | Time(s) 0.0083 | Loss 0.9495 | F1 0.7363 | ETputs(KTEPS) 390.59
# Epoch 00050 | Time(s) 0.0083 | Loss 0.9403 | F1 0.7404 | ETputs(KTEPS) 391.79
# Epoch 00051 | Time(s) 0.0082 | Loss 0.9150 | F1 0.7419 | ETputs(KTEPS) 392.63
# Epoch 00052 | Time(s) 0.0082 | Loss 0.9210 | F1 0.7448 | ETputs(KTEPS) 393.32
# Epoch 00053 | Time(s) 0.0082 | Loss 0.9085 | F1 0.7493 | ETputs(KTEPS) 394.76
# Epoch 00054 | Time(s) 0.0082 | Loss 0.9297 | F1 0.7522 | ETputs(KTEPS) 395.67
# Epoch 00055 | Time(s) 0.0082 | Loss 0.8973 | F1 0.7555 | ETputs(KTEPS) 396.54
# Epoch 00056 | Time(s) 0.0081 | Loss 0.8864 | F1 0.7581 | ETputs(KTEPS) 397.24
# Epoch 00057 | Time(s) 0.0081 | Loss 0.8792 | F1 0.7674 | ETputs(KTEPS) 397.90
# Epoch 00058 | Time(s) 0.0081 | Loss 0.8815 | F1 0.7707 | ETputs(KTEPS) 397.65
# Epoch 00059 | Time(s) 0.0081 | Loss 0.8746 | F1 0.7710 | ETputs(KTEPS) 397.64
# Epoch 00060 | Time(s) 0.0081 | Loss 0.8577 | F1 0.7762 | ETputs(KTEPS) 398.03
# Epoch 00061 | Time(s) 0.0081 | Loss 0.8552 | F1 0.7710 | ETputs(KTEPS) 398.53
# Epoch 00062 | Time(s) 0.0081 | Loss 0.8338 | F1 0.7744 | ETputs(KTEPS) 398.76
# Epoch 00063 | Time(s) 0.0081 | Loss 0.8319 | F1 0.7770 | ETputs(KTEPS) 399.04
# Epoch 00064 | Time(s) 0.0081 | Loss 0.8390 | F1 0.7773 | ETputs(KTEPS) 399.52
# Epoch 00065 | Time(s) 0.0081 | Loss 0.8307 | F1 0.7825 | ETputs(KTEPS) 400.02
# Epoch 00066 | Time(s) 0.0081 | Loss 0.8346 | F1 0.7869 | ETputs(KTEPS) 399.98
# Epoch 00067 | Time(s) 0.0081 | Loss 0.8231 | F1 0.7884 | ETputs(KTEPS) 398.93
# Epoch 00068 | Time(s) 0.0081 | Loss 0.8137 | F1 0.7869 | ETputs(KTEPS) 398.24
# Epoch 00069 | Time(s) 0.0081 | Loss 0.8056 | F1 0.7877 | ETputs(KTEPS) 398.39
# Epoch 00070 | Time(s) 0.0081 | Loss 0.8174 | F1 0.7910 | ETputs(KTEPS) 398.08
# Epoch 00071 | Time(s) 0.0081 | Loss 0.8036 | F1 0.7943 | ETputs(KTEPS) 397.39
# Epoch 00072 | Time(s) 0.0082 | Loss 0.7995 | F1 0.7928 | ETputs(KTEPS) 396.40
# Epoch 00073 | Time(s) 0.0082 | Loss 0.8006 | F1 0.7958 | ETputs(KTEPS) 396.14
# Epoch 00074 | Time(s) 0.0082 | Loss 0.7910 | F1 0.8002 | ETputs(KTEPS) 396.36
# Epoch 00075 | Time(s) 0.0082 | Loss 0.7855 | F1 0.8017 | ETputs(KTEPS) 396.10
# Epoch 00076 | Time(s) 0.0082 | Loss 0.7825 | F1 0.8017 | ETputs(KTEPS) 395.71
# Epoch 00077 | Time(s) 0.0082 | Loss 0.7761 | F1 0.7999 | ETputs(KTEPS) 395.21
# Epoch 00078 | Time(s) 0.0082 | Loss 0.7801 | F1 0.8002 | ETputs(KTEPS) 394.73
# Epoch 00079 | Time(s) 0.0082 | Loss 0.7757 | F1 0.8072 | ETputs(KTEPS) 393.72
# Epoch 00080 | Time(s) 0.0082 | Loss 0.7549 | F1 0.8080 | ETputs(KTEPS) 392.96
# Epoch 00081 | Time(s) 0.0082 | Loss 0.7632 | F1 0.8047 | ETputs(KTEPS) 392.87
# Epoch 00082 | Time(s) 0.0083 | Loss 0.7682 | F1 0.8109 | ETputs(KTEPS) 391.67
# Epoch 00083 | Time(s) 0.0083 | Loss 0.7533 | F1 0.8102 | ETputs(KTEPS) 390.80
# Epoch 00084 | Time(s) 0.0083 | Loss 0.7513 | F1 0.8091 | ETputs(KTEPS) 389.86
# Epoch 00085 | Time(s) 0.0083 | Loss 0.7487 | F1 0.8095 | ETputs(KTEPS) 389.00
# Epoch 00086 | Time(s) 0.0083 | Loss 0.7434 | F1 0.8179 | ETputs(KTEPS) 388.31
# Epoch 00087 | Time(s) 0.0083 | Loss 0.7518 | F1 0.8198 | ETputs(KTEPS) 387.67
# Epoch 00088 | Time(s) 0.0084 | Loss 0.7281 | F1 0.8157 | ETputs(KTEPS) 386.24
# Epoch 00089 | Time(s) 0.0084 | Loss 0.7284 | F1 0.8139 | ETputs(KTEPS) 385.37
# Epoch 00090 | Time(s) 0.0084 | Loss 0.7354 | F1 0.8150 | ETputs(KTEPS) 384.40
# Epoch 00091 | Time(s) 0.0086 | Loss 0.7370 | F1 0.8227 | ETputs(KTEPS) 374.17
# Epoch 00092 | Time(s) 0.0087 | Loss 0.7332 | F1 0.8268 | ETputs(KTEPS) 371.27
# Epoch 00093 | Time(s) 0.0087 | Loss 0.7103 | F1 0.8205 | ETputs(KTEPS) 370.78
# Epoch 00094 | Time(s) 0.0087 | Loss 0.7210 | F1 0.8191 | ETputs(KTEPS) 370.46
# Epoch 00095 | Time(s) 0.0088 | Loss 0.7147 | F1 0.8283 | ETputs(KTEPS) 369.82
# Epoch 00096 | Time(s) 0.0087 | Loss 0.7104 | F1 0.8272 | ETputs(KTEPS) 369.98
# Epoch 00097 | Time(s) 0.0087 | Loss 0.7160 | F1 0.8264 | ETputs(KTEPS) 370.66
# Epoch 00098 | Time(s) 0.0087 | Loss 0.7133 | F1 0.8239 | ETputs(KTEPS) 371.03
# Epoch 00099 | Time(s) 0.0087 | Loss 0.7089 | F1 0.8316 | ETputs(KTEPS) 371.71
# Epoch 00100 | Time(s) 0.0087 | Loss 0.6944 | F1 0.8342 | ETputs(KTEPS) 372.18
# Epoch 00101 | Time(s) 0.0087 | Loss 0.6963 | F1 0.8287 | ETputs(KTEPS) 372.71
# Epoch 00102 | Time(s) 0.0087 | Loss 0.7075 | F1 0.8264 | ETputs(KTEPS) 372.95
# Epoch 00103 | Time(s) 0.0087 | Loss 0.6940 | F1 0.8305 | ETputs(KTEPS) 373.43
# Epoch 00104 | Time(s) 0.0087 | Loss 0.6827 | F1 0.8349 | ETputs(KTEPS) 373.98
# Epoch 00105 | Time(s) 0.0086 | Loss 0.6740 | F1 0.8301 | ETputs(KTEPS) 374.45
# Epoch 00106 | Time(s) 0.0086 | Loss 0.6855 | F1 0.8316 | ETputs(KTEPS) 374.74
# Epoch 00107 | Time(s) 0.0086 | Loss 0.6750 | F1 0.8335 | ETputs(KTEPS) 375.28
# Epoch 00108 | Time(s) 0.0086 | Loss 0.6819 | F1 0.8353 | ETputs(KTEPS) 375.91
# Epoch 00109 | Time(s) 0.0086 | Loss 0.6743 | F1 0.8357 | ETputs(KTEPS) 376.14
# Epoch 00110 | Time(s) 0.0086 | Loss 0.6679 | F1 0.8375 | ETputs(KTEPS) 376.59
# Epoch 00111 | Time(s) 0.0086 | Loss 0.6756 | F1 0.8401 | ETputs(KTEPS) 376.80
# Epoch 00112 | Time(s) 0.0086 | Loss 0.6684 | F1 0.8397 | ETputs(KTEPS) 376.97
# Epoch 00113 | Time(s) 0.0086 | Loss 0.6752 | F1 0.8379 | ETputs(KTEPS) 377.29
# Epoch 00114 | Time(s) 0.0086 | Loss 0.6588 | F1 0.8416 | ETputs(KTEPS) 377.81
# Epoch 00115 | Time(s) 0.0086 | Loss 0.6589 | F1 0.8379 | ETputs(KTEPS) 378.26
# Epoch 00116 | Time(s) 0.0085 | Loss 0.6480 | F1 0.8371 | ETputs(KTEPS) 378.65
# Epoch 00117 | Time(s) 0.0085 | Loss 0.6665 | F1 0.8412 | ETputs(KTEPS) 379.16
# Epoch 00118 | Time(s) 0.0085 | Loss 0.6657 | F1 0.8431 | ETputs(KTEPS) 379.63
# Epoch 00119 | Time(s) 0.0085 | Loss 0.6527 | F1 0.8427 | ETputs(KTEPS) 380.28
# Epoch 00120 | Time(s) 0.0085 | Loss 0.6552 | F1 0.8431 | ETputs(KTEPS) 380.80
# Epoch 00121 | Time(s) 0.0085 | Loss 0.6559 | F1 0.8464 | ETputs(KTEPS) 381.39
# Epoch 00122 | Time(s) 0.0085 | Loss 0.6412 | F1 0.8434 | ETputs(KTEPS) 382.06
# Epoch 00123 | Time(s) 0.0085 | Loss 0.6417 | F1 0.8442 | ETputs(KTEPS) 382.69
# Epoch 00124 | Time(s) 0.0084 | Loss 0.6459 | F1 0.8442 | ETputs(KTEPS) 383.12
# Epoch 00125 | Time(s) 0.0084 | Loss 0.6374 | F1 0.8497 | ETputs(KTEPS) 383.57
# Epoch 00126 | Time(s) 0.0084 | Loss 0.6397 | F1 0.8471 | ETputs(KTEPS) 383.77
# Epoch 00127 | Time(s) 0.0084 | Loss 0.6383 | F1 0.8479 | ETputs(KTEPS) 383.97
# Epoch 00128 | Time(s) 0.0084 | Loss 0.6334 | F1 0.8482 | ETputs(KTEPS) 384.10
# Epoch 00129 | Time(s) 0.0084 | Loss 0.6194 | F1 0.8490 | ETputs(KTEPS) 384.37
# Epoch 00130 | Time(s) 0.0084 | Loss 0.6479 | F1 0.8516 | ETputs(KTEPS) 384.56
# Epoch 00131 | Time(s) 0.0084 | Loss 0.6344 | F1 0.8501 | ETputs(KTEPS) 384.93
# Epoch 00132 | Time(s) 0.0084 | Loss 0.6385 | F1 0.8508 | ETputs(KTEPS) 385.16
# Epoch 00133 | Time(s) 0.0084 | Loss 0.6233 | F1 0.8549 | ETputs(KTEPS) 385.12
# Epoch 00134 | Time(s) 0.0084 | Loss 0.6364 | F1 0.8593 | ETputs(KTEPS) 385.32
# Epoch 00135 | Time(s) 0.0084 | Loss 0.6204 | F1 0.8541 | ETputs(KTEPS) 385.30
# Epoch 00136 | Time(s) 0.0084 | Loss 0.6312 | F1 0.8541 | ETputs(KTEPS) 385.38
# Epoch 00137 | Time(s) 0.0084 | Loss 0.6118 | F1 0.8564 | ETputs(KTEPS) 385.35
# Epoch 00138 | Time(s) 0.0084 | Loss 0.6231 | F1 0.8586 | ETputs(KTEPS) 385.48
# Epoch 00139 | Time(s) 0.0084 | Loss 0.6143 | F1 0.8575 | ETputs(KTEPS) 385.36
# Epoch 00140 | Time(s) 0.0084 | Loss 0.6148 | F1 0.8575 | ETputs(KTEPS) 385.26
# Epoch 00141 | Time(s) 0.0084 | Loss 0.6160 | F1 0.8578 | ETputs(KTEPS) 385.38
# Epoch 00142 | Time(s) 0.0084 | Loss 0.6198 | F1 0.8589 | ETputs(KTEPS) 385.25
# Epoch 00143 | Time(s) 0.0084 | Loss 0.6163 | F1 0.8637 | ETputs(KTEPS) 385.47
# Epoch 00144 | Time(s) 0.0084 | Loss 0.6216 | F1 0.8630 | ETputs(KTEPS) 385.48
# Epoch 00145 | Time(s) 0.0084 | Loss 0.6209 | F1 0.8589 | ETputs(KTEPS) 385.27
# Epoch 00146 | Time(s) 0.0084 | Loss 0.6139 | F1 0.8604 | ETputs(KTEPS) 385.31
# Epoch 00147 | Time(s) 0.0084 | Loss 0.6066 | F1 0.8634 | ETputs(KTEPS) 385.48
# Epoch 00148 | Time(s) 0.0084 | Loss 0.6026 | F1 0.8623 | ETputs(KTEPS) 385.37
# Epoch 00149 | Time(s) 0.0084 | Loss 0.6007 | F1 0.8619 | ETputs(KTEPS) 385.41
# Epoch 00150 | Time(s) 0.0084 | Loss 0.5972 | F1 0.8619 | ETputs(KTEPS) 385.22
# Epoch 00151 | Time(s) 0.0084 | Loss 0.6172 | F1 0.8667 | ETputs(KTEPS) 385.46
# Epoch 00152 | Time(s) 0.0084 | Loss 0.6058 | F1 0.8604 | ETputs(KTEPS) 385.36
# Epoch 00153 | Time(s) 0.0084 | Loss 0.5995 | F1 0.8645 | ETputs(KTEPS) 385.32
# Epoch 00154 | Time(s) 0.0084 | Loss 0.6080 | F1 0.8667 | ETputs(KTEPS) 385.41
# Epoch 00155 | Time(s) 0.0084 | Loss 0.6065 | F1 0.8682 | ETputs(KTEPS) 385.53
# Epoch 00156 | Time(s) 0.0084 | Loss 0.6082 | F1 0.8652 | ETputs(KTEPS) 385.54
# Epoch 00157 | Time(s) 0.0084 | Loss 0.6010 | F1 0.8674 | ETputs(KTEPS) 385.81
# Epoch 00158 | Time(s) 0.0084 | Loss 0.5981 | F1 0.8689 | ETputs(KTEPS) 385.81
# Epoch 00159 | Time(s) 0.0084 | Loss 0.6015 | F1 0.8678 | ETputs(KTEPS) 385.88
# Epoch 00160 | Time(s) 0.0084 | Loss 0.5802 | F1 0.8660 | ETputs(KTEPS) 386.09
# Epoch 00161 | Time(s) 0.0084 | Loss 0.5896 | F1 0.8660 | ETputs(KTEPS) 386.37
# Epoch 00162 | Time(s) 0.0084 | Loss 0.5998 | F1 0.8722 | ETputs(KTEPS) 386.68
# Epoch 00163 | Time(s) 0.0084 | Loss 0.5817 | F1 0.8652 | ETputs(KTEPS) 386.96
# Epoch 00164 | Time(s) 0.0084 | Loss 0.6062 | F1 0.8700 | ETputs(KTEPS) 387.16
# Epoch 00165 | Time(s) 0.0084 | Loss 0.5908 | F1 0.8708 | ETputs(KTEPS) 387.47
# Epoch 00166 | Time(s) 0.0083 | Loss 0.5877 | F1 0.8726 | ETputs(KTEPS) 387.72
# Epoch 00167 | Time(s) 0.0083 | Loss 0.5882 | F1 0.8696 | ETputs(KTEPS) 387.96
# Epoch 00168 | Time(s) 0.0083 | Loss 0.5781 | F1 0.8730 | ETputs(KTEPS) 387.99
# Epoch 00169 | Time(s) 0.0083 | Loss 0.5826 | F1 0.8722 | ETputs(KTEPS) 387.87
# Epoch 00170 | Time(s) 0.0083 | Loss 0.5762 | F1 0.8693 | ETputs(KTEPS) 387.72
# Epoch 00171 | Time(s) 0.0084 | Loss 0.5640 | F1 0.8693 | ETputs(KTEPS) 387.46
# Epoch 00172 | Time(s) 0.0084 | Loss 0.5779 | F1 0.8737 | ETputs(KTEPS) 387.35
# Epoch 00173 | Time(s) 0.0084 | Loss 0.5856 | F1 0.8733 | ETputs(KTEPS) 387.12
# Epoch 00174 | Time(s) 0.0084 | Loss 0.5817 | F1 0.8752 | ETputs(KTEPS) 387.03
# Epoch 00175 | Time(s) 0.0084 | Loss 0.5829 | F1 0.8748 | ETputs(KTEPS) 386.98
# Epoch 00176 | Time(s) 0.0084 | Loss 0.5670 | F1 0.8737 | ETputs(KTEPS) 387.23
# Epoch 00177 | Time(s) 0.0084 | Loss 0.5802 | F1 0.8770 | ETputs(KTEPS) 387.24
# Epoch 00178 | Time(s) 0.0084 | Loss 0.5729 | F1 0.8759 | ETputs(KTEPS) 387.30
# Epoch 00179 | Time(s) 0.0084 | Loss 0.5698 | F1 0.8737 | ETputs(KTEPS) 387.32
# Epoch 00180 | Time(s) 0.0084 | Loss 0.5783 | F1 0.8767 | ETputs(KTEPS) 387.26
# Epoch 00181 | Time(s) 0.0084 | Loss 0.5784 | F1 0.8781 | ETputs(KTEPS) 387.12
# Epoch 00182 | Time(s) 0.0084 | Loss 0.5752 | F1 0.8752 | ETputs(KTEPS) 387.05
# Epoch 00183 | Time(s) 0.0084 | Loss 0.5708 | F1 0.8774 | ETputs(KTEPS) 387.01
# Epoch 00184 | Time(s) 0.0084 | Loss 0.5771 | F1 0.8770 | ETputs(KTEPS) 387.07
# Epoch 00185 | Time(s) 0.0084 | Loss 0.5727 | F1 0.8756 | ETputs(KTEPS) 387.04
# Epoch 00186 | Time(s) 0.0084 | Loss 0.5703 | F1 0.8752 | ETputs(KTEPS) 386.97
# Epoch 00187 | Time(s) 0.0084 | Loss 0.5723 | F1 0.8807 | ETputs(KTEPS) 387.06
# Epoch 00188 | Time(s) 0.0084 | Loss 0.5643 | F1 0.8785 | ETputs(KTEPS) 387.05
# Epoch 00189 | Time(s) 0.0084 | Loss 0.5665 | F1 0.8744 | ETputs(KTEPS) 387.03
# Epoch 00190 | Time(s) 0.0084 | Loss 0.5528 | F1 0.8774 | ETputs(KTEPS) 387.22
# Epoch 00191 | Time(s) 0.0084 | Loss 0.5700 | F1 0.8804 | ETputs(KTEPS) 387.36
# Epoch 00192 | Time(s) 0.0084 | Loss 0.5668 | F1 0.8815 | ETputs(KTEPS) 387.40
# Epoch 00193 | Time(s) 0.0084 | Loss 0.5487 | F1 0.8781 | ETputs(KTEPS) 387.37
# Epoch 00194 | Time(s) 0.0084 | Loss 0.5693 | F1 0.8796 | ETputs(KTEPS) 387.30
# Epoch 00195 | Time(s) 0.0084 | Loss 0.5735 | F1 0.8818 | ETputs(KTEPS) 387.26
# Epoch 00196 | Time(s) 0.0084 | Loss 0.5674 | F1 0.8811 | ETputs(KTEPS) 387.18
# Epoch 00197 | Time(s) 0.0084 | Loss 0.5689 | F1 0.8815 | ETputs(KTEPS) 387.21
# /Users/mikhail-makarov/opt/anaconda3/envs/graph_text/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#
#
#
#
#
#
#
#
#
#
#
#
#
# seeds: 100%|██████████| 1/1 [00:04<00:00,  4.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# test_ratios: 100%|██████████| 4/4 [00:25<00:00,  6.07s/it]
# Epoch 00198 | Time(s) 0.0084 | Loss 0.5639 | F1 0.8815 | ETputs(KTEPS) 387.20
# Epoch 00199 | Time(s) 0.0084 | Loss 0.5533 | F1 0.8840 | ETputs(KTEPS) 387.20
# Tasks: 100%|██████████| 1/1 [03:01<00:00, 181.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# datasets: 100%|██████████| 1/1 [03:01<00:00, 181.69s/it]
# {'0.5 - Cora - GCN (W2V)': [0.7327520849128127], '0.30000000000000004 - Cora - GCN (W2V)': [0.7224478743568914], '0.09999999999999998 - Cora - GCN (W2V)': [0.6864603074331438], '0.050000000000000044 - Cora - GCN (W2V)': [0.6627767803710353]}

# %%
for name, scores in res.items():
    print(name, scores, np.mean(scores), np.std(scores))
# Out:
# 0.5 - Cora - GCN (W2V) [0.7327520849128127] 0.7327520849128127 0.0
# 0.30000000000000004 - Cora - GCN (W2V) [0.7224478743568914] 0.7224478743568914 0.0
# 0.09999999999999998 - Cora - GCN (W2V) [0.6864603074331438] 0.6864603074331438 0.0
# 0.050000000000000044 - Cora - GCN (W2V) [0.6627767803710353] 0.6627767803710353 0.0
